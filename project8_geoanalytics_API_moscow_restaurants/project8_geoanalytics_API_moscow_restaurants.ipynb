# %% [markdown]
# # Рынок заведений общественного питания Москвы

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Вы решили открыть небольшое кафе в Москве. Оно оригинальное — гостей должны обслуживать роботы. Проект многообещающий, но дорогой. Вместе с партнёрами вы решились обратиться к инвесторам. Их интересует текущее положение дел на рынке — сможете ли вы снискать популярность на долгое время, когда все зеваки насмотрятся на роботов-официантов? Партнёры просят вас подготовить исследование рынка. У вас есть открытые данные о заведениях общественного питания в Москве.
#
# **Сделайте общий вывод и дайте рекомендации о виде заведения, количестве посадочных мест, а также районе расположения. Прокомментируйте возможность развития сети. Выводы подготовьте в формате PDF-презентации.**

# %% [markdown]
# ## Структура проекта

# %% [markdown]
# 1. [Знакомство с данными](#1)
# 2. [Предобработка](#2)
# 3. [Вычленение улицы из адреса. RegEx](#3)
# 4. [Получение геоданных по адресу. Работа с API](#4)
# 5. [Обогащение данных информацией о населении районов](#5)
# 6. [EDA](#6)
# 7. [Результаты исследования](#7)

# %% [markdown]
# ## Прекод

# %%
# !pip install plotly -U
# !pip install pymorphy2 -U
# !pip install geocoder -U
# Out:
# Requirement already satisfied: plotly in /shared-libs/python3.7/py/lib/python3.7/site-packages (4.14.3)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from plotly) (1.16.0)
# Requirement already satisfied: retrying>=1.3.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly) (1.3.3)
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.5 MB/s
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 14.7 MB/s
# Requirement already satisfied: docopt>=0.6 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pymorphy2) (0.6.2)
# Installing collected packages: pymorphy2-dicts-ru, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 9.5 MB/s
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from geocoder) (2.25.1)
# Requirement already satisfied: future in /shared-libs/python3.7/py/lib/python3.7/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from geocoder) (7.1.2)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ratelim->geocoder) (5.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->geocoder) (1.26.4)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
# игнорируем предупреждения
import warnings
warnings.filterwarnings('ignore')

# работа с таблицамими, вычисления
import numpy as np
import pandas as pd
from scipy import stats as st

# регулярки
import re 

# для импорта файла из Google Sheets
import requests
from io import BytesIO

# для приведения названия районов к нормальной форме для мерджа таблиц
import pymorphy2

# Google Geocoding API, парсинг геоданных
import geocoder

# для приватного хранения токена
import os


# визуализация
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# параметры визуализации
sns.set()
sns.set_context(
    "notebook", 
    font_scale=1.3,       
    rc={ 
        "figure.figsize": (12, 10), 
        "axes.titlesize": 18 
    }
)
from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 10

# параметры отображения таблиц
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 1. Знакомство с данными <a name="1"></a>

# %%
LINK = ''
PRAKTIKUM_DIR = '/datasets/'

REST_DATA = 'rest_data.csv'

# %%
try:
    raw_df = pd.read_csv(PRAKTIKUM_DIR+REST_DATA)
    print('Файлы прочитаны. Работаем в среде Я.Практикума')
except:
    raw_df = pd.read_csv(LINK+REST_DATA)
    print('Данные прочитаны. Работаем вне среды Я.Практикума')
# Out:
# Данные прочитаны. Работаем вне среды Я.Практикума

# %%
print('Размерность raw_df:', raw_df.shape)
# Out:
# Размерность raw_df: (15366, 6)

# %%
raw_df.sample(10, random_state=42)
# Out:
#            id            object_name chain                object_type  \
# 12062  182973            БУРГЕР КИНГ    да                       кафе
# 8819   156321       Кафе «Тетя Мотя»   нет                       кафе
# 14197  206042             Чебуречная   нет  магазин (отдел кулинарии)
# 6081   156891   Чудо Пекарня Шаргунь   нет                 закусочная
# 2478    27730  Столовая «ГАЛА ПИЦЦА»   нет                   столовая
# 1370   154280              Пиво-воды   нет                        бар
# 12664  201989                Пекарня   нет                 закусочная
# 14930  223189         Porto-Pomodoro   нет                   ресторан
# 3889    25948                 Форбес   нет                   ресторан
# 6338   152835     Диктатура Эстетика   нет                       кафе
#
#                                                          address  number
# 12062                    город Москва, Ярославское шоссе, дом 69      60
# 8819           город Москва, проезд Сокольнического Круга, дом 7     100
# 14197            город Москва, Открытое шоссе, дом 9, строение 9       0
# 6081    город Москва, Севастопольский проспект, дом 15, корпус 3       0
# 2478                     город Москва, Варшавское шоссе, дом 116      46
# 1370            город Москва, Щёлковское шоссе, дом 85, корпус 1      22
# 12664           город Москва, Липецкая улица, дом 50, строение 2       0
# 14930                     город Москва, Ходынский бульвар, дом 4       0
# 3889   город Москва, Подколокольный переулок, дом 13, строение 1      88
# 6338    город Москва, Берсеневская набережная, дом 6, строение 2      38

# %% [markdown]
# **Описание столбцов**

# %% [markdown]
# * id — идентификатор объекта;
# * object_name — название объекта общественного питания;
# * chain — сетевой ресторан;
# * object_type — тип объекта общественного питания;
# * address — адрес;
# * number — количество посадочных мест.

# %% [markdown]
# Посмотрим на распределение уникальных значений в столбцах

# %%
for col in raw_df.columns:
    display(raw_df[col].value_counts())
# Out:
# 163840    1
# 207007    1
# 58806     1
# 198074    1
# 150035    1
#          ..
# 29419     1
# 69506     1
# 23278     1
# 185071    1
# 167934    1
# Name: id, Length: 15366, dtype: int64
# Столовая           267
# Кафе               236
# Шаурма             234
# KFC                155
# Шоколадница        142
#                   ...
# Мама, я в лапшу      1
# Кафе «Лайк»          1
# АРИАДНА              1
# Апрель               1
# МУГАН                1
# Name: object_name, Length: 10393, dtype: int64
# нет    12398
# да      2968
# Name: chain, dtype: int64
# кафе                                 6099
# столовая                             2587
# ресторан                             2285
# предприятие быстрого обслуживания    1923
# бар                                   856
# буфет                                 585
# кафетерий                             398
# закусочная                            360
# магазин (отдел кулинарии)             273
# Name: object_type, dtype: int64
# город Москва, Ходынский бульвар, дом 4                           95
# город Москва, Пресненская набережная, дом 2                      63
# город Москва, проспект Мира, дом 211, корпус 2                   60
# город Москва, Кировоградская улица, дом 13А                      53
# город Москва, площадь Киевского Вокзала, дом 2                   48
#                                                                  ..
# город Москва, проспект 60-летия Октября, дом 23                   1
# город Москва, Сколковское шоссе, дом 32, корпус 1                 1
# город Москва, Варшавское шоссе, дом 144, корпус 2, строение 2     1
# город Москва, улица Образцова, дом 9, строение 4                  1
# город Москва, Осенний бульвар, дом 9                              1
# Name: address, Length: 9108, dtype: int64
# 0      1621
# 40      835
# 20      727
# 30      685
# 10      644
#        ...
# 172       1
# 520       1
# 680       1
# 760       1
# 495       1
# Name: number, Length: 315, dtype: int64

# %%
raw_df['number'].describe()
# Out:
# count    15366.000000
# mean        59.547182
# std         74.736833
# min          0.000000
# 25%         12.000000
# 50%         40.000000
# 75%         80.000000
# max       1700.000000
# Name: number, dtype: float64

# %%
raw_df.query('number == 0').shape[0] / raw_df.shape[0]
# Out:
# 0.10549264610178316

# %% [markdown]
# ### Вывод
#
# - имеем разные регистры в значениях столбцов `object_name` и `adress`. Нужно привести к единому регистру для корректного учета дубликатов и уникальных значений.
# - столбец `address` потребует выделения названия улицы из полного адреса для анализа популярных улиц согласно заданию.
# - типы данных корректны, пропусков нет.
# - дубликаты проверим на этапе предобработки.
# - около 10.5% записей-ресторанов имеют 0 посадных мест. Нули могут быть характерны для заведений с 'едой на вынос'. Не будем считать это ошибкой в данных.

# %% [markdown]
# ## 2. Предобработка <a name="2"></a>

# %% [markdown]
# Делаем копию изначальных данных. Приводим значения столбцов `object_name` и `adress` к единому нижнему регистру.

# %%
df = raw_df.copy()

# %%
df[['object_name', 'address']] = raw_df[['object_name', 'address']].applymap(lambda x: x.lower())

# %% [markdown]
# Сравним результат `.value_counts()` для этих столбцов: их изначальный вид VS приведенный к нижнему регистру.

# %%
display(raw_df['object_name'].value_counts().head(10))
display(df['object_name'].value_counts().head(10))
# Out:
# Столовая           267
# Кафе               236
# Шаурма             234
# KFC                155
# Шоколадница        142
# Макдоналдс         122
# Бургер Кинг        122
# Домино'с Пицца      86
# Теремок             84
# Крошка Картошка     82
# Name: object_name, dtype: int64
# столовая           321
# кафе               278
# шаурма             250
# шоколадница        158
# kfc                155
# макдоналдс         151
# бургер кинг        137
# теремок             94
# крошка картошка     90
# домино'с пицца      90
# Name: object_name, dtype: int64

# %%
display(raw_df['address'].value_counts().head(10))
display(df['address'].value_counts().head(10))
# Out:
# город Москва, Ходынский бульвар, дом 4            95
# город Москва, Пресненская набережная, дом 2       63
# город Москва, проспект Мира, дом 211, корпус 2    60
# город Москва, Кировоградская улица, дом 13А       53
# город Москва, площадь Киевского Вокзала, дом 2    48
# город Москва, улица Земляной Вал, дом 33          46
# город Москва, Мытная улица, дом 74                46
# город Москва, улица Новый Арбат, дом 21           42
# город Москва, улица Ленинская Слобода, дом 26     41
# город Москва, Ярцевская улица, дом 19             40
# Name: address, dtype: int64
# город москва, ходынский бульвар, дом 4            95
# город москва, пресненская набережная, дом 2       63
# город москва, проспект мира, дом 211, корпус 2    60
# город москва, кировоградская улица, дом 13а       53
# город москва, площадь киевского вокзала, дом 2    48
# город москва, улица земляной вал, дом 33          46
# город москва, мытная улица, дом 74                46
# город москва, улица новый арбат, дом 21           42
# город москва, улица ленинская слобода, дом 26     41
# город москва, кутузовский проспект, дом 57        40
# Name: address, dtype: int64

# %% [markdown]
# - приведение названий объектов питания `object_name` к нижнему регистру действительно помогло убрать дубликаты.
# - однако в случае со столбцом `address` ничего не изменилось. Вернем этому столбцу изначальные адреса с наличием заглавных букв для лучшей читабельности.

# %%
df['address'] = raw_df['address']

# %%
df.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %% [markdown]
# Дубликаты будем искать по строке за исключением столбца `id`, т.к. все айдишники уникальны, значит поиск дубликатов с этим столбцом ничего не даст. Также проверим дубликаты без учета кол-ва посадочных мест `number`.

# %%
print('Количество полных дубликатов:', df.duplicated().sum())
print('Количество дубликатов без столбца id:', df.iloc[:, 1:].duplicated().sum())
print('Количество дубликатов без столбцов id и number:', df.iloc[:, 1:-1].duplicated().sum())
# Out:
# Количество полных дубликатов: 0
# Количество дубликатов без столбца id: 85
# Количество дубликатов без столбцов id и number: 183

# %% [markdown]
# Второй вариант показал больше дубликатов, значит у ряда заведений полностью совпадает название, категория, адрес, но различается количество посадочных мест. Возможно ли такое в реальности? Вряд ли. Посмотрим на эти строки.

# %%
df[df.iloc[:, 1:-1].duplicated()].sample(10, random_state=42)
# Out:
#            id                   object_name chain  \
# 4462    26394        центр павла слободкина   нет
# 5393    71373                закусочная kfc    да
# 14204  207883                  пунк питания   нет
# 12193  192574  каменев василий владимирович   нет
# 13216  194256             кафе «white cafe»   нет
# 3481    20914                    буфет мади   нет
# 5060    20015                          lift   нет
# 6537    23787              столовая при мгу   нет
# 12734  192923                          lift   нет
# 11372  190471                         буфет   нет
#
#                              object_type  \
# 4462                               буфет
# 5393   предприятие быстрого обслуживания
# 14204                               кафе
# 12193                               кафе
# 13216                               кафе
# 3481                               буфет
# 5060                                кафе
# 6537                            столовая
# 12734                               кафе
# 11372                              буфет
#
#                                                      address  number
# 4462           город Москва, улица Арбат, дом 48, строение 1      55
# 5393          город Москва, проспект Мира, дом 211, корпус 2      86
# 14204      город Москва, Большая Черкизовская улица, дом 125       0
# 12193  город Москва, улица Сущёвский Вал, дом 5, строение 12       2
# 13216     город Москва, Краснопресненская набережная, дом 12       8
# 3481            город Москва, Ленинградский проспект, дом 64      40
# 5060   город Москва, Багратионовский проезд, дом 7, корпус 1      40
# 6537          город Москва, территория Ленинские Горы, дом 1      40
# 12734  город Москва, Багратионовский проезд, дом 7, корпус 3       3
# 11372                  город Москва, Пятницкое шоссе, дом 18       0

# %% [markdown]
# Удаляем эти 183 строки. Для повторающихся строк-дублей оставляем только одну уникальную запись.

# %%
df.columns[1:-1].to_list()
# Out:
# ['object_name', 'chain', 'object_type', 'address']

# %%
df = df.drop_duplicates(subset=df.columns[1:-1].to_list())

# %%
print(raw_df.shape[0])
print(df.shape[0])
# Out:
# 15366
# 15183

# %% [markdown]
# ## 3. Вычленение улицы из адреса. RegEx <a name="3"></a>

# %% [markdown]
# Теперь выделим названия улиц из адресов. Посмотрим на выборку адресов.

# %%
display(df['address'].sample(30, random_state=42))
# Out:
# 12535                           Вознесенский переулок, дом 7, строение 1
# 11343                           город Москва, Бартеневская улица, дом 59
# 6237                                город Москва, Венёвская улица, дом 4
# 3850                       город Москва, 1-й переулок Тружеников, дом 18
# 6824                            город Москва, Дубравная улица, дом 34/29
# 10399                      город Москва, Новогиреевская улица, дом 31/45
# 11758            город Москва, Пресненская набережная, дом 4, строение 1
# 7872        город Москва, Сибирский проезд, дом 2, корпус 27, строение 1
# 3587                      город Москва, Старопименовский переулок, дом 5
# 12743               город Москва, улица Сущёвский Вал, дом 5, строение 5
# 7042                город Москва, Дмитровское шоссе, дом 108, строение 7
# 5404                      город Москва, проспект Мира, дом 211, корпус 2
# 1166                           город Москва, Тимирязевская улица, дом 19
# 12539        город Москва, Большая Грузинская улица, дом 30А, строение 1
# 11501                    город Москва, Каширское шоссе, дом 76, корпус 7
# 12419                       город Москва, улица Хамовнический Вал, дом 2
# 11113                          город Москва, улица Сущёвский Вал, дом 18
# 10556                              город Москва, Цимлянская улица, дом 2
# 9298             город Москва, Пресненская набережная, дом 4, строение 1
# 13257    город Москва, поселение Московский, улица Татьянин Парк, дом 11
# 2887                        город Москва, Ясный проезд, дом 10, корпус 3
# 9768                           город Москва, Мичуринский проспект, дом 5
# 2621                      город Москва, Нагорная улица, дом 26, корпус 1
# 4906                            город Москва, улица Сущёвский Вал, дом 2
# 2319                 город Москва, Измайловское шоссе, дом 71, корпус 2Б
# 1748                          город Москва, Мосфильмовская улица, дом 53
# 12173         город Москва, улица Коровий Вал, владение 11, сооружение 1
# 9063                         город Москва, Кронштадтский бульвар, дом 47
# 15274                город Москва, микрорайон Северное Чертаново, дом 1А
# 15146                город Москва, Шереметьевская улица, дом 6, корпус 1
# Name: address, dtype: object

# %%
steet_synonyms = ['улица','ул', 'ул.', 'переулок','шоссе','проспект','площадь',
'проезд','аллея','бульвар','набережная','тупик','линия', 'просек', 'квартал', 
'микрорайон', 'территория', 'километр']

# %%
# test_pattern = r".*,\s*\b([^,]*?(?:{})\b[^,]*)[,$]+".format("|".join(steet_synonyms))
pattern =  r'(([а-яА-ЯёЁ0-9-й\s]+)?({})+([а-яА-ЯёЁ0-9-й\s]+)?)'.format('|'.join(steet_synonyms))

# %%
df["address"].str.extract(pattern, flags=re.I).head()
# Out:
#                         0                 1      2                 3
# 0   улица Егора Абакумова                    улица   Егора Абакумова
# 1        улица Талалихина                    улица        Талалихина
# 2    Абельмановская улица   Абельмановская   улица               NaN
# 3      Абрамцевская улица     Абрамцевская   улица               NaN
# 4      Абрамцевская улица     Абрамцевская   улица               NaN

# %%
df["street"] = df["address"].str.extract(pattern, flags=re.I)[0]

# %% [markdown]
# Посмотрим, успешно ли паттерн вычленил улицы из адресов.

# %%
with pd.option_context('display.max_colwidth', None):
    display(df[['address', 'street']].sample(30, random_state=42))
# Out:
#                                                                address  \
# 12535                         Вознесенский переулок, дом 7, строение 1
# 11343                         город Москва, Бартеневская улица, дом 59
# 6237                              город Москва, Венёвская улица, дом 4
# 3850                     город Москва, 1-й переулок Тружеников, дом 18
# 6824                          город Москва, Дубравная улица, дом 34/29
# 10399                    город Москва, Новогиреевская улица, дом 31/45
# 11758          город Москва, Пресненская набережная, дом 4, строение 1
# 7872      город Москва, Сибирский проезд, дом 2, корпус 27, строение 1
# 3587                    город Москва, Старопименовский переулок, дом 5
# 12743             город Москва, улица Сущёвский Вал, дом 5, строение 5
# 7042              город Москва, Дмитровское шоссе, дом 108, строение 7
# 5404                    город Москва, проспект Мира, дом 211, корпус 2
# 1166                         город Москва, Тимирязевская улица, дом 19
# 12539      город Москва, Большая Грузинская улица, дом 30А, строение 1
# 11501                  город Москва, Каширское шоссе, дом 76, корпус 7
# 12419                     город Москва, улица Хамовнический Вал, дом 2
# 11113                        город Москва, улица Сущёвский Вал, дом 18
# 10556                            город Москва, Цимлянская улица, дом 2
# 9298           город Москва, Пресненская набережная, дом 4, строение 1
# 13257  город Москва, поселение Московский, улица Татьянин Парк, дом 11
# 2887                      город Москва, Ясный проезд, дом 10, корпус 3
# 9768                         город Москва, Мичуринский проспект, дом 5
# 2621                    город Москва, Нагорная улица, дом 26, корпус 1
# 4906                          город Москва, улица Сущёвский Вал, дом 2
# 2319               город Москва, Измайловское шоссе, дом 71, корпус 2Б
# 1748                        город Москва, Мосфильмовская улица, дом 53
# 12173       город Москва, улица Коровий Вал, владение 11, сооружение 1
# 9063                       город Москва, Кронштадтский бульвар, дом 47
# 15274              город Москва, микрорайон Северное Чертаново, дом 1А
# 15146              город Москва, Шереметьевская улица, дом 6, корпус 1
#
#                                street
# 12535           Вознесенский переулок
# 11343              Бартеневская улица
# 6237                  Венёвская улица
# 3850          1-й переулок Тружеников
# 6824                  Дубравная улица
# 10399            Новогиреевская улица
# 11758          Пресненская набережная
# 7872                 Сибирский проезд
# 3587        Старопименовский переулок
# 12743             улица Сущёвский Вал
# 7042                Дмитровское шоссе
# 5404                    проспект Мира
# 1166              Тимирязевская улица
# 12539        Большая Грузинская улица
# 11501                 Каширское шоссе
# 12419         улица Хамовнический Вал
# 11113             улица Сущёвский Вал
# 10556                Цимлянская улица
# 9298           Пресненская набережная
# 13257             улица Татьянин Парк
# 2887                     Ясный проезд
# 9768             Мичуринский проспект
# 2621                   Нагорная улица
# 4906              улица Сущёвский Вал
# 2319               Измайловское шоссе
# 1748             Мосфильмовская улица
# 12173               улица Коровий Вал
# 9063            Кронштадтский бульвар
# 15274   микрорайон Северное Чертаново
# 15146            Шереметьевская улица

# %%
df['street'].value_counts().head(10)
# Out:
#  проспект Мира             196
#  Профсоюзная улица         180
#  Ленинградский проспект    170
#  Пресненская набережная    165
#  Варшавское шоссе          162
#  Ленинский проспект        147
#  проспект Вернадского      126
#  Кутузовский проспект      114
#  Каширское шоссе           110
#  Кировоградская улица      107
# Name: street, dtype: int64

# %%
df['street'].isna().sum() / df.shape[0]
# Out:
# 0.016202331555028652

# %% [markdown]
# Около 1.6% наблюдений не получили улиц. Посмотрим на выборку из этих строк.

# %%
with pd.option_context('display.max_colwidth', None):
    display(df[['address', 'street']].query('street.isna()').sample(30, random_state=42))
# Out:
#                                                                                       address  \
# 2413                                  город Москва, город Зеленоград, корпус 317А, строение 1
# 1412                                              город Москва, город Зеленоград, корпус 1449
# 11739           город Москва, поселение Московский, деревня Саларьево, владение 3, строение 1
# 8563                       город Москва, поселение Рязановское, посёлок Знамя Октября, дом 39
# 10840                                              город Москва, город Зеленоград, корпус 142
# 11736           город Москва, поселение Московский, деревня Саларьево, владение 3, строение 1
# 12121                                             город Москва, город Зеленоград, корпус 1805
# 8620                              город Москва, поселение Сосенское, деревня Сосенки, дом 126
# 1612                                              город Москва, город Зеленоград, корпус 1805
# 14811                   город Москва, поселение Воскресенское, посёлок Воскресенское, дом 22А
# 14473                                            город Москва, город Зеленоград, корпус 1602А
# 13306                              город Москва, поселение Сосенское, деревня Сосенки, дом 73
# 14819  город Москва, поселение Воскресенское, посёлок Воскресенское, владение 54А, строение 1
# 11437                                 город Москва, город Зеленоград, корпус 317А, строение 1
# 7231                                              город Москва, город Зеленоград, корпус 1637
# 13785                      город Москва, поселение Краснопахорское, село Красная Пахра, дом 5
# 13686                                             город Москва, город Зеленоград, корпус 1106
# 1859                               город Москва, поселение Внуковское, деревня Ликова, дом 1А
# 11740           город Москва, поселение Московский, деревня Саларьево, владение 3, строение 1
# 1880                              город Москва, поселение Щаповское, деревня Овечкино, дом 42
# 8924                              город Москва, поселение Вороновское, деревня Бабенки, дом 1
# 1875                           город Москва, поселение Московский, деревня Говорово, дом 1Б/Н
# 8735                                              город Москва, город Зеленоград, корпус 1651
# 7236                                              город Москва, город Зеленоград, корпус 1549
# 13783                              город Москва, поселение Сосенское, деревня Сосенки, дом 39
# 10841                                              город Москва, город Зеленоград, корпус 711
# 12459                                             город Москва, город Зеленоград, корпус 1805
# 1794                                               город Москва, город Зеленоград, корпус 533
# 1894                             город Москва, поселение Московский, деревня Лапшинка, дом 2Б
# 8573                            город Москва, поселение Рязановское, посёлок Остафьево, дом 1
#
#       street
# 2413     NaN
# 1412     NaN
# 11739    NaN
# 8563     NaN
# 10840    NaN
# 11736    NaN
# 12121    NaN
# 8620     NaN
# 1612     NaN
# 14811    NaN
# 14473    NaN
# 13306    NaN
# 14819    NaN
# 11437    NaN
# 7231     NaN
# 13785    NaN
# 13686    NaN
# 1859     NaN
# 11740    NaN
# 1880     NaN
# 8924     NaN
# 1875     NaN
# 8735     NaN
# 7236     NaN
# 13783    NaN
# 10841    NaN
# 12459    NaN
# 1794     NaN
# 1894     NaN
# 8573     NaN

# %% [markdown]
# Названия улиц не получили в основном территории за МКАДом типа Зеленограда, различных поселений и деревень, в которых не было названий улиц.
#
# Мы не будем пытаться учесть их как улицы, так как:
# - во-первых, территории за МКАДом для робо-ресторана вряд ли будут перспективными;
# - во-вторых, неправильно с точки зрения здравого смысла ставить, например, город Зеленоград в один ряд с обычными улицами. Зеленоград не улица, и в эту группу  может попасть слишком много домов;

# %% [markdown]
# ## 4. Получение геоданных по адресу. Работа с API <a name="4"></a>

# %% [markdown]
# Считываем токен доступа к API. Его значение хранится в переменной окружения (в целях приватности).

# %%
GMAPS_TOKEN = os.environ['GMAPS_TOKEN']

# %%
df['address'].sample(1, random_state=42)
# Out:
# 12535    Вознесенский переулок, дом 7, строение 1
# Name: address, dtype: object

# %%
g_example = geocoder.google(df['address'].sample(1, random_state=42), key=GMAPS_TOKEN, language="RU")

# %%
g_example.json
# Out:
# {'accuracy': 'ROOFTOP',
#  'address': 'Вознесенский пер., 7, Москва, Россия, 125009',
#  'bbox': {'northeast': [55.7595139802915, 37.6050719802915],
#   'southwest': [55.7568160197085, 37.6023740197085]},
#  'city': 'Москва',
#  'confidence': 9,
#  'country': 'RU',
#  'county': 'Москва',
#  'housenumber': '7',
#  'lat': 55.758165,
#  'lng': 37.603723,
#  'ok': True,
#  'place': 'ChIJac8yOE9KtUYRXmjvgRXf-lA',
#  'postal': '125009',
#  'quality': 'street_address',
#  'raw': {'address_components': [{'long_name': '7',
#     'short_name': '7',
#     'types': ['street_number']},
#    {'long_name': 'Вознесенский переулок',
#     'short_name': 'Вознесенский пер.',
#     'types': ['route']},
#    {'long_name': 'Центральный административный округ',
#     'short_name': 'Центральный административный округ',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Москва',
#     'short_name': 'Москва',
#     'types': ['locality', 'political']},
#    {'long_name': 'Пресненский',
#     'short_name': 'Пресненский',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'Москва',
#     'short_name': 'Москва',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Россия',
#     'short_name': 'RU',
#     'types': ['country', 'political']},
#    {'long_name': '125009', 'short_name': '125009', 'types': ['postal_code']}],
#   'formatted_address': 'Вознесенский пер., 7, Москва, Россия, 125009',
#   'geometry': {'location': {'lat': 55.758165, 'lng': 37.603723},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 55.7595139802915,
#      'lng': 37.6050719802915},
#     'southwest': {'lat': 55.7568160197085, 'lng': 37.6023740197085}}},
#   'place_id': 'ChIJac8yOE9KtUYRXmjvgRXf-lA',
#   'plus_code': {'compound_code': 'QJ53+7F Пресненский район, Москва, Россия',
#    'global_code': '9G7VQJ53+7F'},
#   'types': ['street_address'],
#   'street_number': {'long_name': '7', 'short_name': '7'},
#   'route': {'long_name': 'Вознесенский переулок',
#    'short_name': 'Вознесенский пер.'},
#   'political': {'long_name': 'Россия', 'short_name': 'RU'},
#   'sublocality': {'long_name': 'Центральный административный округ',
#    'short_name': 'Центральный административный округ'},
#   'sublocality_level_1': {'long_name': 'Центральный административный округ',
#    'short_name': 'Центральный административный округ'},
#   'locality': {'long_name': 'Москва', 'short_name': 'Москва'},
#   'administrative_area_level_3': {'long_name': 'Пресненский',
#    'short_name': 'Пресненский'},
#   'administrative_area_level_2': {'long_name': 'Москва',
#    'short_name': 'Москва'},
#   'country': {'long_name': 'Россия', 'short_name': 'RU'},
#   'postal_code': {'long_name': '125009', 'short_name': '125009'}},
#  'status': 'OK',
#  'street': 'Вознесенский пер.',
#  'sublocality': 'Центральный административный округ'}

# %%
g_example.json['raw']['address_components'][2]['short_name']
# Out:
# 'Центральный административный округ'

# %%
g_example.json['raw']['address_components'][4]['short_name']
# Out:
# 'Пресненский'

# %%
list(g_example.json['raw']['geometry']['location'].values())
# Out:
# [55.758165, 37.603723]

# %%
g_example.json.get('raw').get('sublocality_level_1').get('short_name')
# Out:
# 'Центральный административный округ'

# %%
g_example.json.get('raw').get('administrative_area_level_3').get('short_name')
# Out:
# 'Пресненский'

# %%
[g_example.json.get('lat'), g_example.json.get('lng')]
# Out:
# [55.758165, 37.603723]

# %%
g_example.latlng

# %%
g_example.json.get('street')
# Out:
# 'Вознесенский пер.'

# %% [markdown]
# Разобрались в структуре JSON-ответа.
#
# Теперь для отладки спарсим данные для тестовой выборки из 20 адресов (чтобы случайно не спарсить не то, что нам нужно, для всех 15 тыс. адресов).

# %%
address_sample = df['address'].sample(20, random_state=42)

# %%
address_sample.head(20)
# Out:
# 12535                           Вознесенский переулок, дом 7, строение 1
# 11343                           город Москва, Бартеневская улица, дом 59
# 6237                                город Москва, Венёвская улица, дом 4
# 3850                       город Москва, 1-й переулок Тружеников, дом 18
# 6824                            город Москва, Дубравная улица, дом 34/29
# 10399                      город Москва, Новогиреевская улица, дом 31/45
# 11758            город Москва, Пресненская набережная, дом 4, строение 1
# 7872        город Москва, Сибирский проезд, дом 2, корпус 27, строение 1
# 3587                      город Москва, Старопименовский переулок, дом 5
# 12743               город Москва, улица Сущёвский Вал, дом 5, строение 5
# 7042                город Москва, Дмитровское шоссе, дом 108, строение 7
# 5404                      город Москва, проспект Мира, дом 211, корпус 2
# 1166                           город Москва, Тимирязевская улица, дом 19
# 12539        город Москва, Большая Грузинская улица, дом 30А, строение 1
# 11501                    город Москва, Каширское шоссе, дом 76, корпус 7
# 12419                       город Москва, улица Хамовнический Вал, дом 2
# 11113                          город Москва, улица Сущёвский Вал, дом 18
# 10556                              город Москва, Цимлянская улица, дом 2
# 9298             город Москва, Пресненская набережная, дом 4, строение 1
# 13257    город Москва, поселение Московский, улица Татьянин Парк, дом 11
# Name: address, dtype: object

# %%
address_sample_df = pd.DataFrame(columns=['address', 'admin_district', 'district', 'lat_lng_geocode'])

# %%
for address in address_sample:
    
    g = geocoder.google(
        address,
        key=GMAPS_TOKEN, 
        language="RU"
        )

    address_sample_df.loc[len(address_sample_df.index)] = [
        address, 
        g.json['raw']['address_components'][2]['short_name'], 
        g.json['raw']['address_components'][4]['short_name'], 
        list(g.json['raw']['geometry']['location'].values())
        ]

# %%
address_sample_df.head(20)
# Out:
#                                                             address  \
# 0                          Вознесенский переулок, дом 7, строение 1
# 1                          город Москва, Бартеневская улица, дом 59
# 2                              город Москва, Венёвская улица, дом 4
# 3                     город Москва, 1-й переулок Тружеников, дом 18
# 4                          город Москва, Дубравная улица, дом 34/29
# 5                     город Москва, Новогиреевская улица, дом 31/45
# 6           город Москва, Пресненская набережная, дом 4, строение 1
# 7      город Москва, Сибирский проезд, дом 2, корпус 27, строение 1
# 8                    город Москва, Старопименовский переулок, дом 5
# 9              город Москва, улица Сущёвский Вал, дом 5, строение 5
# 10             город Москва, Дмитровское шоссе, дом 108, строение 7
# 11                   город Москва, проспект Мира, дом 211, корпус 2
# 12                        город Москва, Тимирязевская улица, дом 19
# 13      город Москва, Большая Грузинская улица, дом 30А, строение 1
# 14                  город Москва, Каширское шоссе, дом 76, корпус 7
# 15                     город Москва, улица Хамовнический Вал, дом 2
# 16                        город Москва, улица Сущёвский Вал, дом 18
# 17                            город Москва, Цимлянская улица, дом 2
# 18          город Москва, Пресненская набережная, дом 4, строение 1
# 19  город Москва, поселение Московский, улица Татьянин Парк, дом 11
#
#                              admin_district               district  \
# 0        Центральный административный округ            Пресненский
# 1       Юго-Западный административный округ           Южное Бутово
# 2       Юго-Западный административный округ           Южное Бутово
# 3        Центральный административный округ              Хамовники
# 4    Северо-Западный административный округ                 Митино
# 5          Восточный административный округ                 Перово
# 6        Центральный административный округ            Пресненский
# 7        Центральный административный округ              Таганский
# 8        Центральный административный округ               Тверской
# 9   Северо-Восточный административный округ           Марьина Роща
# 10          Северный административный округ     Восточное Дегунино
# 11  Северо-Восточный административный округ               Свиблово
# 12          Северный административный округ          Тимирязевский
# 13       Центральный административный округ            Пресненский
# 14               Юж. административный округ   Москворечье-сабурово
# 15       Центральный административный округ              Хамовники
# 16  Северо-Восточный административный округ           Марьина Роща
# 17     Юго-Восточный административный округ                Люблино
# 18       Центральный административный округ            Пресненский
# 19                Новомосковский Адм. округ  Московский, Поселение
#
#                            lat_lng_geocode
# 0                   [55.758165, 37.603723]
# 1   [55.54617260000001, 37.51593769999999]
# 2          [55.54855200000001, 37.5424999]
# 3                  [55.737041, 37.5715081]
# 4                  [55.846367, 37.3580737]
# 5                 [55.7542051, 37.7999832]
# 6                 [55.7489662, 37.5432141]
# 7                   [55.729826, 37.682961]
# 8          [55.76932249999999, 37.6004401]
# 9                   [55.794884, 37.594743]
# 10          [55.88502099999999, 37.548736]
# 11                [55.8448991, 37.6598303]
# 12         [55.8129108, 37.56646750000001]
# 13                  [55.766229, 37.581083]
# 14                 [55.640235, 37.6785734]
# 15                  [55.716131, 37.576643]
# 16                [55.7918967, 37.6036636]
# 17          [55.671619, 37.77407729999999]
# 18                [55.7489662, 37.5432141]
# 19                [55.6583479, 37.4223299]

# %% [markdown]
# Убедились на выборке, что и геокодер, и написанный цикл работают корректно.
#
# Теперь можем применить аналогичный цикл к основному датафрейму. Для экономии лимита по запросам и оптимизации времени будем парсить только уникальные адреса.

# %%
df.shape[0]
# Out:
# 15183

# %%
df['address'].unique().shape[0]
# Out:
# 9108

# %%
uniq_addresses = df['address'].unique().tolist()

# %% [markdown]
# Ряд проверочек

# %%
uniq_addresses[:5]
# Out:
# ['город Москва, улица Егора Абакумова, дом 9',
#  'город Москва, улица Талалихина, дом 2/1, корпус 1',
#  'город Москва, Абельмановская улица, дом 6',
#  'город Москва, Абрамцевская улица, дом 1',
#  'город Москва, Абрамцевская улица, дом 9, корпус 1']

# %%
len(uniq_addresses)
# Out:
# 9108

# %%
# address_sample_df.to_csv('address_sample_df.csv', index=False)

# %%
GEODATA_TABLE_ID = '1rINFl9QmkSRuEKvFHxQeYUZIOd814vp5PnfItqL4FHs'
geodata_path = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(GEODATA_TABLE_ID)

try:
    geodata_r = requests.get(geodata_path)
    geodata = pd.read_csv(BytesIO(geodata_r.content))
    print('Файл прочитан из Google Sheets')
except:
    try:
        geodata = pd.read_csv('geodata.csv')
        print('Файл прочитан из CSV-файла окружения')
    except:
        geodata = pd.DataFrame(columns=['address', 'admin_district', 'district', 'lat_lng_geocode'])
        print('Сформирован пустой фрейм')
# Out:
# Файл прочитан из Google Sheets

# %%
len(geodata.index)
# Out:
# 9094

# %% [markdown]
# **Код запроса к Geocoding API исполнялся около 40-50 минут. Оставляю код закоменченным. Результат парсинга сохранен в `geodata.csv` и закинут в Google Sheets, откуда теперь и подтягивается в проект (код чуть выше).**
#
# P.S. Правильнее было бы обращаться к полученному `JSON` черещ `.get()`, а не через обычную индексацию, т.к. get понятнее и отказоустойчивее в случае, если структура JSON отличается (имеет место быть для некоторых ошибочных адресов).

# %%
# # счетчик для периодической перезаписи фрейма в CSV-файл,
# # чтобы не терять все данные в переменной, если ядро умрет
# counter = len(geodata.index)

# for address in uniq_addresses[len(geodata.index):]:
#     try:
#         g = geocoder.google(
#             address,
#             key=GMAPS_TOKEN, 
#             language="RU"
#             )

#         geodata.loc[len(geodata.index)] = [
#             address, 
#             g.json['raw']['address_components'][2]['short_name'], 
#             g.json['raw']['address_components'][4]['short_name'], 
#             list(g.json['raw']['geometry']['location'].values())
#             ]
#     except:
#         pass
        
    
#     # каждые 200 наполненных инфой строк фрейма перезаписываем фрейм в CSV-файл
#     counter += 1
#     if counter % 200 == 0:
#         geodata.to_csv('geodata.csv', index=False)

# %%
len(uniq_addresses)
# Out:
# 9108

# %%
geodata.shape[0]
# Out:
# 9094

# %% [markdown]
# В ходе парсинга не получили корректный JSON-ответ по 14 адресам из 9108. Не критично.

# %%
geodata.tail()
# Out:
#                                                              address  \
# 9089  город Москва, Профсоюзная улица, дом 142, корпус 1, строение 1
# 9090                          город Москва, Привольная улица, дом 11
# 9091                        город Москва, Салтыковская улица, дом 7Г
# 9092                            город Москва, Осенний бульвар, дом 9
# 9093                         город Москва, улица Новый Арбат, дом 13
#
#                             admin_district         district  \
# 9089   Юго-Западный административный округ      Теплый Стан
# 9090  Юго-Восточный административный округ  Выхино-жулебино
# 9091                      ул. Салтыковская           Москва
# 9092       Западный административный округ       Крылатское
# 9093    Центральный административный округ            Арбат
#
#                       lat_lng_geocode
# 9089           [55.625528, 37.509222]
# 9090         [55.7007394, 37.8393061]
# 9091         [55.7336033, 37.8616594]
# 9092  [55.7582702, 37.40664750000001]
# 9093           [55.752016, 37.593721]

# %%
geodata['address'].duplicated().sum()
# Out:
# 0

# %%
geodata['admin_district'].value_counts().head(20)
# Out:
# Центральный административный округ         2324
# Юж. административный округ                 1043
# Северо-Восточный административный округ     897
# Восточный административный округ            838
# Северный административный округ             821
# Юго-Западный административный округ         705
# Юго-Восточный административный округ        694
# Западный административный округ             679
# Северо-Западный административный округ      487
# Новомосковский Адм. округ                   149
# Зеленоград                                  108
# Москва                                       65
# Зеленоградский административный округ        60
# Троицкий Адм. округ                          53
# Ленинский р-н                                17
# Подольский район                             13
# Наро-Фоминский р-н                            7
# Подольский р-н                                6
# Троицкое                                      5
# Красная Пахра                                 4
# Name: admin_district, dtype: int64

# %% [markdown]
# Ряд адресов получил названия-синонимы административных регионов. Например, Зеленоградск и Зеленоградский АО - одно и то же.
#
# Не будем обрабатывать эти значения, т.к. не интересен Зеленоград. Крупнейшие АО распределены адекватно и указаны верно.
#
# Однако посмотрим какие строки получили АО 'Москва'.

# %%
geodata[['admin_district', 'district']].query('admin_district == "Москва"')['district'].value_counts()
# Out:
# Москва            37
# RU                13
# Ленинский р-н      8
# МО                 5
# Подольский р-н     2
# Name: district, dtype: int64

# %% [markdown]
# По ряду адресов имеем неверные значения административных районов `admin_district` и районов `district`. Вероятно, по этим адресам полученные JSON-ответы не имели корректной информации об АО и районе адреса. Возможно, в этих адресах ошибки.
#
# Присвоим неверными значениям значение `np.NaN`.

# %%
wrong_districts = ['RU', 'Москва', 'МО']

# %%
geodata.loc[(geodata['admin_district'].isin(wrong_districts)), 'admin_district'] = np.NaN
geodata.loc[(geodata['district'].isin(wrong_districts)), 'district'] = np.NaN

# %%
geodata.isna().sum()
# Out:
# address              0
# admin_district      65
# district           317
# lat_lng_geocode      0
# dtype: int64

# %%
geodata['district'].value_counts().head(20)
# Out:
# Тверской              393
# Пресненский           342
# Басманный             310
# Хамовники             259
# Таганский             240
# Замоскворечье         230
# Мещанский             180
# Даниловский           180
# Красносельский        137
# Якиманка              123
# Арбат                 116
# Соколиная Гора        104
# Марьино               102
# Южное Бутово           98
# Беговой                98
# Лефортово              96
# Митино                 95
# Хорошевский            95
# Нагатино-садовники     94
# Раменки                94
# Name: district, dtype: int64

# %% [markdown]
# Убрали Москву, RU и МО из районов. Теперь районы выглядят адекватно.
#
# Наконец, можем смерджить полученный фрейм `geodata` с основным `df` по ключу `address`.

# %%
df2 = df.merge(geodata, on='address', how='outer')

# %%
df.shape[0]
# Out:
# 15183

# %%
df2.shape[0]
# Out:
# 15183

# %%
df2.isna().sum()
# Out:
# id                   0
# object_name          0
# chain                0
# object_type          0
# address              0
# number               0
# street             246
# admin_district     126
# district           521
# lat_lng_geocode     18
# dtype: int64

# %% [markdown]
# Пропуски в улицах, АО и районе оставим. Посмотрим на пропуски в координатах `lat_lng_geocode`

# %%
df2.query('lat_lng_geocode.isna()')
# Out:
#            id                        object_name chain  \
# 5943    82566                     столовая квант   нет
# 6838    27515                          школа 448   нет
# 7245    24507                            вардзия   нет
# 8107   147847                        новые формы   нет
# 8108   152684                              нофар   нет
# 8367   144529                             сабвей    да
# 8397    20059                           якитория    да
# 8971    20198  петрол комплекс эквипмент компани   нет
# 11369  158795                            чайхона   нет
# 11435   19800                    набатчиков а.п.   нет
# 11790  162723                                kfc    да
# 13707  186731                               пиво   нет
# 13708  175912                          lafka bar   нет
# 13709  204095                      pasta + salsa   нет
# 13710  214114                    армянский лаваш   нет
# 14406  196055                     ресторан «big»   нет
# 14974  208246                             сахара   нет
# 15071  223183                             шаурма   нет
#
#                              object_type  \
# 5943                            столовая
# 6838                            столовая
# 7245                            ресторан
# 8107                            ресторан
# 8108                            ресторан
# 8367                                кафе
# 8397                            ресторан
# 8971                           кафетерий
# 11369                               кафе
# 11435                              буфет
# 11790  предприятие быстрого обслуживания
# 13707                                бар
# 13708                               кафе
# 13709                           ресторан
# 13710                               кафе
# 14406                           ресторан
# 14974                           ресторан
# 15071                              буфет
#
#                                                                               address  \
# 5943                 город Москва, город Зеленоград, проезд № 4801, дом 7, строение 1
# 6838                               город Москва, посёлок Акулово, дом 43А, строение 1
# 7245                      город Москва, шоссе Энтузиастов, домовладение 4, строение 1
# 8107                           город Москва, Кутузовский проспект, дом 12, строение 3
# 8108                           город Москва, Кутузовский проспект, дом 12, строение 3
# 8367          город Москва, 74-й километр Московской Кольцевой Автодороги, владение 4
# 8397               город Москва, 73-й километр Московской Кольцевой Автодороги, дом 7
# 8971                 город Москва, город Зеленоград, проезд № 4801, дом 3, строение 1
# 11369                   город Москва, поселение "Мосрентген", деревня Дудкино, дом 66
# 11435                                  Проектируемый проезд N 5231, дом 8, строение 3
# 11790                      город Москва, Каскадная улица, домовладение 21, строение 1
# 13707  город Москва, поселение Воскресенское, посёлок Воскресенское, дом 40, корпус 2
# 13708  город Москва, поселение Воскресенское, посёлок Воскресенское, дом 40, корпус 2
# 13709  город Москва, поселение Воскресенское, посёлок Воскресенское, дом 40, корпус 2
# 13710  город Москва, поселение Воскресенское, посёлок Воскресенское, дом 40, корпус 2
# 14406                    город Москва, проектируемый проезд № 4062, дом 6, строение 8
# 14974    город Москва, 73-й километр Московской Кольцевой Автодороги, дом 7, корпус 1
# 15071   город Москва, поселение Воскресенское, посёлок Воскресенское, дом 9, корпус 1
#
#        number                                          street admin_district  \
# 5943       60                                         проезд             NaN
# 6838      156                                 посёлок Акулово            NaN
# 7245      250                               шоссе Энтузиастов            NaN
# 8107       35                            Кутузовский проспект            NaN
# 8108      100                            Кутузовский проспект            NaN
# 8367        8   74-й километр Московской Кольцевой Автодороги            NaN
# 8397       90   73-й километр Московской Кольцевой Автодороги            NaN
# 8971       12                                         проезд             NaN
# 11369      42                                             NaN            NaN
# 11435      20                           Проектируемый проезд             NaN
# 11790      20                                 Каскадная улица            NaN
# 13707      10                                             NaN            NaN
# 13708      10                                             NaN            NaN
# 13709      12                                             NaN            NaN
# 13710       0                                             NaN            NaN
# 14406     320                           проектируемый проезд             NaN
# 14974      70   73-й километр Московской Кольцевой Автодороги            NaN
# 15071       0                                             NaN            NaN
#
#       district lat_lng_geocode
# 5943       NaN             NaN
# 6838       NaN             NaN
# 7245       NaN             NaN
# 8107       NaN             NaN
# 8108       NaN             NaN
# 8367       NaN             NaN
# 8397       NaN             NaN
# 8971       NaN             NaN
# 11369      NaN             NaN
# 11435      NaN             NaN
# 11790      NaN             NaN
# 13707      NaN             NaN
# 13708      NaN             NaN
# 13709      NaN             NaN
# 13710      NaN             NaN
# 14406      NaN             NaN
# 14974      NaN             NaN
# 15071      NaN             NaN

# %% [markdown]
# Ряд адресов типа 'проектируемый проезд' не гуглится. Их, вероятно, по крайней мере на данный момент не существует.
#
# Все эти адреса не получили корректной информации ни по координатам, ни по району, ни по АО. Удалим эти строки.

# %%
df2 = df2.query('lat_lng_geocode.notna()')

# %%
df2.isna().sum()
# Out:
# id                   0
# object_name          0
# chain                0
# object_type          0
# address              0
# number               0
# street             240
# admin_district     108
# district           503
# lat_lng_geocode      0
# dtype: int64

# %%
df2.sample(10, random_state=42)
# Out:
#            id          object_name chain                        object_type  \
# 3691   156171              донерок   нет                               кафе
# 12287  170678             донер №1   нет  предприятие быстрого обслуживания
# 12019  163950             столовая   нет                           столовая
# 4629   169706            тажинерия   нет                               кафе
# 13953  190895            магбургер    да                           ресторан
# 3248    24857             бухарест   нет                               кафе
# 2861   167297       ресторан «cut»   нет                           ресторан
# 6631   150878                 вгик   нет                           столовая
# 14889  206181  дом татарской кухни   нет                               кафе
# 10431   24924               кружка    да                               кафе
#
#                                                              address  number  \
# 3691          город Москва, Кронштадтский бульвар, дом 3, строение 3       0
# 12287             город Москва, Ботаническая улица, дом 41, корпус 7       0
# 12019           город Москва, Алтуфьевское шоссе, дом 31, строение 1      80
# 4629                             город Москва, Усачёва улица, дом 26      12
# 13953  город Москва, поселение Щаповское, деревня Троицкое, дом 3Б/Н      24
# 3248                             город Москва, улица Каховка, дом 27      70
# 2861     город Москва, Большая Никитская улица, дом 14/2, строение 7      40
# 6631          город Москва, улица Вильгельма Пика, дом 3, строение 1     200
# 14889              город Москва, улица Касаткина, дом 13, строение 9      20
# 10431                           город Москва, Ладожская улица, дом 5      95
#
#                          street                           admin_district  \
# 3691      Кронштадтский бульвар          Северный административный округ
# 12287        Ботаническая улица  Северо-Восточный административный округ
# 12019        Алтуфьевское шоссе  Северо-Восточный административный округ
# 4629              Усачёва улица       Центральный административный округ
# 13953                       NaN                                 Троицкое
# 3248              улица Каховка      Юго-Западный административный округ
# 2861    Большая Никитская улица       Центральный административный округ
# 6631      улица Вильгельма Пика  Северо-Восточный административный округ
# 14889           улица Касаткина  Северо-Восточный административный округ
# 10431           Ладожская улица       Центральный административный округ
#
#            district           lat_lng_geocode
# 3691    Головинский    [55.840864, 37.484727]
# 12287       Марфино    [55.846276, 37.583892]
# 12019      Отрадное    [55.861476, 37.580076]
# 4629      Хамовники  [55.7272093, 37.5690324]
# 13953           NaN  [55.3881616, 37.4195508]
# 3248         Зюзино   [55.655364, 37.5720159]
# 2861    Пресненский   [55.7567331, 37.605561]
# 6631      Ростокино    [55.834543, 37.638318]
# 14889  Алексеевский    [55.826119, 37.665587]
# 10431     Басманный  [55.7716129, 37.6821536]

# %% [markdown]
# ## 5. Обогащение данных информацией о населении районов <a name="5"></a>

# %% [markdown]
# В идеале для целей исследования было бы хорошо подтянуть информацию о потоке людей по адресу, однако такие данные:
# - либо стоят денег;
# - либо вовсе отсутствуют и требуют сбора (например, гео-аналитические услуги на аутсорсе, что может быть очень дорого).
#
# В качестве достаточно грубой аппроксимации потока людей подгрузим данные о населении районов и смерджим их с нашими. Данные о населении районов взяты с сайта ФСГС по г. Москве и МО, отредактированы под нужный вид и залиты на Google Sheets, откуда мы и будем их читать.
#
# Ссылка на источник:
# https://mosstat.gks.ru/folder/64634. Файл: *Оценка численности постоянного населения г.Москвы на 1 января 2020 года*.

# %%
DISTRICTS_POP_TABLE_ID = '1S0KKKtgHCV7A8e1pKyReD25NmkTCL_pUWkZG3QeOQls'
pop_path = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(DISTRICTS_POP_TABLE_ID)
pop_r = requests.get(pop_path)
pop_df = pd.read_csv(BytesIO(pop_r.content))

# %%
print(pop_df.shape)
pop_df.head()
# Out:
# (173, 2)
#                                                    district        pop
# 0                                           Восточный округ  1527316.0
# 1  в том числе муниципальные образования Восточного округа:        NaN
# 2                                               Богородское   110137.0
# 3                                                   Вешняки   122419.0
# 4                                       Восточное Измайлово    78206.0

# %%
pop_df = pop_df.query('district.str.contains("округ", case=False)==False').sort_values(by='district')

# %%
pop_df.head()

# %% [markdown]
# Проверим, одинаково ли записаны названия районов в подгруженной информации о популяции и наших данных.

# %%
uniq_districts = df2['district'].dropna().unique()

# %%
uniq_districts[:5]
# Out:
# array(['Ярославский', 'Таганский', 'Лианозово', 'Арбат', 'Лефортово'],
#       dtype=object)

# %%
district_names_diff = sorted(list(set(pop_df['district']).symmetric_difference(uniq_districts)))

# %%
district_names_diff[:10]
# Out:
# ['Академический',
#  'Академическое',
#  'Алексеевский',
#  'Алексеевское',
#  'Алтуфьевский',
#  'Алтуфьевское',
#  'Бабушкинский',
#  'Бабушкинское',
#  'Басманное',
#  'Басманный']

# %% [markdown]
# Имеем разные окончания для названий районов в `pop_df` и `df2`. Это не позволит нам смерджить эти таблички по району корректно.
#
# Приведем все названия районов к их нормальной форме.

# %%
morph = pymorphy2.MorphAnalyzer()

for word in district_names_diff[:10]:
    print(morph.parse(word)[0].normal_form)
# Out:
# академический
# академический
# алексеевский
# алексеевский
# алтуфьевский
# алтуфьевский
# бабушкинский
# бабушкинский
# басманный
# басманный

# %%
pop_df['morph_district'] = pop_df['district'].map(lambda x: morph.parse(x)[0].normal_form)

# %%
pop_df.head()
# Out:
#           district       pop morph_district
# 115  Академическое  110038.0  академический
# 60    Алексеевское   80634.0   алексеевский
# 61    Алтуфьевское   57697.0   алтуфьевский
# 89           Арбат   36308.0          арбат
# 42        Аэропорт   79541.0       аэропорт

# %%
df3 = df2.copy()

# %%
df3['morph_district'] = (
    df3['district']
    .replace(np.nan, 'nan')
    .map(lambda x: morph.parse(x)[0].normal_form)
    .replace('nan', np.nan)
    )

# %%
df3[['district','morph_district']].sample(20, random_state=42)
# Out:
#             district morph_district
# 3691     Головинский    головинский
# 12287        Марфино        марфино
# 12019       Отрадное       отрадный
# 4629       Хамовники       хамовник
# 13953            NaN            NaN
# 3248          Зюзино         зюзино
# 2861     Пресненский    пресненский
# 6631       Ростокино      ростокино
# 14889   Алексеевский   алексеевский
# 10431      Басманный      басманный
# 4716       Басманный      басманный
# 1944         Марьино        марьино
# 251            Сокол          сокол
# 7519        Котловка       котловка
# 3902    Алтуфьевский   алтуфьевский
# 4767      Ивановское     ивановский
# 12020  Замоскворечье  замоскворечье
# 4602       Хамовники       хамовник
# 7225         Люблино        люблино
# 4013       Измайлово      измайлово

# %%
df3.merge(pop_df, on='morph_district', how='inner').shape[0] / df3.shape[0]
# Out:
# 0.9186943620178042

# %% [markdown]
# После обработки, около 92% записей в `df3` имеют названия районов, соответствующие названиям из `pop_df`.
#
# Будем использовать **LEFT JOIN** и, соответственно, получим около 8% записей с пропусками в столбце населения района `pop`. Приемлемо.

# %%
df3 = df3.merge(pop_df[['morph_district', 'pop']], on='morph_district', how='left')

# %%
df3[['morph_district', 'district', 'pop']].sample(20, random_state=42)
# Out:
#       morph_district       district       pop
# 3691     головинский    Головинский  103573.0
# 12276        марфино        Марфино   35579.0
# 12008       отрадный       Отрадное  185745.0
# 4629        хамовник      Хамовники  109451.0
# 13938            NaN            NaN       NaN
# 3248          зюзино         Зюзино  127301.0
# 2861     пресненский    Пресненский  128314.0
# 6630       ростокино      Ростокино   40196.0
# 14873   алексеевский   Алексеевский   80634.0
# 10423      басманный      Басманный  110897.0
# 4716       басманный      Басманный  110897.0
# 1944         марьино        Марьино  254142.0
# 251            сокол          Сокол   60171.0
# 7516        котловка       Котловка   65992.0
# 3902    алтуфьевский   Алтуфьевский   57697.0
# 4767      ивановский     Ивановское  128514.0
# 12009  замоскворечье  Замоскворечье   59305.0
# 4602        хамовник      Хамовники  109451.0
# 7223         люблино        Люблино  172523.0
# 4013       измайлово      Измайлово  107883.0

# %%
df3 = df3.drop(columns='morph_district')

# %%
'morph_district' in df3.columns
# Out:
# False

# %% [markdown]
# ## 6. EDA <a name="6"></a>

# %% [markdown]
# Согласно поставленным задачам, нужно исследовать:
#
# - соотношение видов объектов общественного питания по количеству;
# - соотношение сетевых и несетевых заведений по количеству;
# - для какого вида объекта общественного питания характерно сетевое распространение;
# - что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест;
# - среднее количество посадочных мест для каждого вида объекта общественного питания. Какой вид предоставляет в среднем самое большое количество посадочных мест;
# - топ-10 улиц по количеству объектов общественного питания, а также в каких районах Москвы находятся эти улицы;
# - число улиц с одним объектом общественного питания. В каких районах Москвы находятся эти улицы;
# - распределение количества посадочных мест для улиц с большим количеством объектов общественного питания, описать закономерности.
#
# Идем по порядку. В конце раздела попытаемся дать окончательный результат анализа с использованием информации о населении районов.

# %%
object_types_counts = df3['object_type'].value_counts()

# %%
fig = px.bar(
    object_types_counts,
    text=object_types_counts,
    color=object_types_counts.index,
    labels={'index':'object_type', 'value':'count'},
    title='Наиболее популярные категории объектов общественного питания'
    )

fig.update_layout(showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="53c6a64c-da5d-44c3-b38a-39a8bad50706" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53c6a64c-da5d-44c3-b38a-39a8bad50706")) {                    Plotly.newPlot(                        "53c6a64c-da5d-44c3-b38a-39a8bad50706",                        [{"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>count=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "\u043a\u0430\u0444\u0435", "marker": {"color": "#636efa"}, "name": "\u043a\u0430\u0444\u0435", "offsetgroup": "\u043a\u0430\u0444\u0435", "orientation": "v", "showlegend": true, "text": [6004.0], "textposition": "auto", "type": "bar", "x": ["\u043a\u0430\u0444\u0435"], "xaxis": "x", "y": [6004], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>count=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "\u0441\u0442\u043e\u043b\u043e\u0432\u0430\u044f", "marker": {"color": "#EF553B"}, "name": "\u0441\u0442\u043e\u043b\u043e\u0432\u0430\u044f", "offsetgroup": "\u0441\u0442\u043e\u043b\u043e\u0432\u0430\u044f", "orientation": "v", "showlegend": true, "text": [2573.0], "textposition": "auto", "type": "bar", "x": ["\u0441\u0442\u043e\u043b\u043e\u0432\u0430\u044f"], "xaxis": "x", "y": [2573], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>count=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "marker": {"color": "#00cc96"}, "name": "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "offsetgroup": "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "orientation": "v", "showlegend": true, "text": [2268.0], "textposition": "auto", "type": "bar", "x": ["\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d"], "xaxis": "x", "y": [2268], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>count=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "marker": {"color": "#ab63fa"}, "name": "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "offsetgroup": "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "orientation": "v", "showlegend": true, "text": [1889.0], "textposition": "auto", "type": "bar", "x": ["\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f"], "xaxis": "x", "y": [1889], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>count=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "\u0431\u0430\u0440", "marker": {"color": "#FFA15A"}, "name": "\u0431\u0430\u0440", "offsetgroup": "\u0431\u0430\u0440", "orientation": "v", "showlegend": true, "text": [852.0], "textposition": "auto", "type": "bar", "x": ["\u0431\u0430\u0440"], "xaxis": "x", "y": [852], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>count=%{y}<br>text=%{text}<extra></extra>", "legendgroup": "\u0431\u0443\u0444\u0435\u0442", "marker": {"color": "#19d3f3"}, "name": "\u0431\u0443\u0444\u0435\u0442", "offsetgroup": "\u0431\u0443\u0444\u0435\u0442", "orientation": "v", "showlegend": true, "text": [568.0], "textposition": "auto", "type": "bar", "x": ["\u0431\u0443\u0444\u0435\u0442"], "xaxis": "x", "y": [568], " ...

# %% [markdown]
# - категория кафе лидирует с отрывом (~40% всех объектов общественного питания - кафе);
# - на четверку категорий-лидеров приходится ~80% всех объектов общественного питания;
#
# Предполагается, что наш робо-ресторан как раз будет кафе — самым популярным форматом заведений.

# %%
chain_object_type_report = (
    df3
    .groupby(['object_type', 'chain'])
    .agg({'id':'count'})
    .reset_index()
    .rename(columns={'id':'is_chain_count'})
    )

# %%
chain_object_type_report.head()
# Out:
#   object_type chain  is_chain_count
# 0         бар    да              37
# 1         бар   нет             815
# 2       буфет    да              11
# 3       буфет   нет             557
# 4  закусочная    да              56

# %%
object_type_g = (
    df3
    .groupby(['object_type'])
    .agg({'id':'count'})
    .reset_index()
    .rename(columns={'id':'count'})
    )

# %%
object_type_g.head()
# Out:
#   object_type  count
# 0         бар    852
# 1       буфет    568
# 2  закусочная    347
# 3        кафе   6004
# 4   кафетерий    392

# %%
chain_object_type_report = chain_object_type_report.merge(object_type_g, on='object_type')

# %%
chain_object_type_report['is_chain_share'] = (chain_object_type_report['is_chain_count'] / chain_object_type_report['count']).round(3)

# %%
chain_object_type_report.head()
# Out:
#   object_type chain  is_chain_count  count  is_chain_share
# 0         бар    да              37    852           0.043
# 1         бар   нет             815    852           0.957
# 2       буфет    да              11    568           0.019
# 3       буфет   нет             557    568           0.981
# 4  закусочная    да              56    347           0.161

# %%
fig = px.bar(
    (
        chain_object_type_report
        .query('chain == "да"')
        .sort_values(by='is_chain_share', ascending=False)
    ), 
    x='object_type', 
    y='is_chain_share', 
    color='object_type',
    text='is_chain_share',
    labels={
        'is_chain_share':'Доля сетевых объектов',
        'object_type':'Категория объекта'
        },
    title='Наибольшая доля сетевых объектов общественного питания по категориям'

    )

fig.update_traces(texttemplate='%{text:.1%}')
fig.layout.yaxis.tickformat = ',.0%'
fig.update_layout(showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="7aac7548-2dd4-46d9-a2e4-ce7b8e8967a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7aac7548-2dd4-46d9-a2e4-ce7b8e8967a9")) {                    Plotly.newPlot(                        "7aac7548-2dd4-46d9-a2e4-ce7b8e8967a9",                        [{"alignmentgroup": "True", "hovertemplate": "\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u044f \u043e\u0431\u044a\u0435\u043a\u0442\u0430=%{x}<br>\u0414\u043e\u043b\u044f \u0441\u0435\u0442\u0435\u0432\u044b\u0445 \u043e\u0431\u044a\u0435\u043a\u0442\u043e\u0432=%{text}<extra></extra>", "legendgroup": "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "marker": {"color": "#636efa"}, "name": "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "offsetgroup": "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "orientation": "v", "showlegend": true, "text": [0.415], "textposition": "auto", "texttemplate": "%{text:.1%}", "type": "bar", "x": ["\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f"], "xaxis": "x", "y": [0.415], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u044f \u043e\u0431\u044a\u0435\u043a\u0442\u0430=%{x}<br>\u0414\u043e\u043b\u044f \u0441\u0435\u0442\u0435\u0432\u044b\u0445 \u043e\u0431\u044a\u0435\u043a\u0442\u043e\u0432=%{text}<extra></extra>", "legendgroup": "\u043c\u0430\u0433\u0430\u0437\u0438\u043d (\u043e\u0442\u0434\u0435\u043b \u043a\u0443\u043b\u0438\u043d\u0430\u0440\u0438\u0438)", "marker": {"color": "#EF553B"}, "name": "\u043c\u0430\u0433\u0430\u0437\u0438\u043d (\u043e\u0442\u0434\u0435\u043b \u043a\u0443\u043b\u0438\u043d\u0430\u0440\u0438\u0438)", "offsetgroup": "\u043c\u0430\u0433\u0430\u0437\u0438\u043d (\u043e\u0442\u0434\u0435\u043b \u043a\u0443\u043b\u0438\u043d\u0430\u0440\u0438\u0438)", "orientation": "v", "showlegend": true, "text": [0.287], "textposition": "auto", "texttemplate": "%{text:.1%}", "type": "bar", "x": ["\u043c\u0430\u0433\u0430\u0437\u0438\u043d (\u043e\u0442\u0434\u0435\u043b \u043a\u0443\u043b\u0438\u043d\u0430\u0440\u0438\u0438)"], "xaxis": "x", "y": [0.287], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u044f \u043e\u0431\u044a\u0435\u043a\u0442\u0430=%{x}<br>\u0414\u043e\u043b\u044f \u0441\u0435\u0442\u0435\u0432\u044b\u0445 \u043e\u0431\u044a\u0435\u043a\u0442\u043e\u0432=%{text}<extra></extra>", "legendgroup": "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "marker": {"color": "#00cc96"}, "name": "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "offsetgroup": "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "orientation": "v", "showlegend": true, "text": [0.239], "textposition": "auto", "texttemplate": "%{text:.1%}", "type": "bar", "x": ["\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d"], "xaxis": "x", "y": [0.239], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u044f \u043e\u0431\u044a\u0435\u043a\u0442\u0430=%{x}<br>\u0414\u043e\u043b\u044f \u0441\u0435\u0442\u0435\u0432\u044b\u0445 \u043e\u0431\u044a\u0435\u043a\u0442\u043e\u0432=%{text}<extra></extra>", "legendgroup": "\u043a\u043 ...

# %% [markdown]
# - вполне интуитивно, что предприятия быстрого обслуживания имеют наивысшую долю сетевых заведений (можно было ожидать долю еще выше);
# - интересно, что для баров крайне нехарактерно сетевое распространение;
#
# Так или иначе, вряд ли для открытия робо-ресторана получится опираться на уже готовую франшизу.

# %%
px.box(
    df3, 
    x='number', 
    color='chain',
    labels={'number':'Количество посадочных мест', 'chain':'Сеть'},
    title='Характерное количество посадочных мест (сетевые заведения против несетевых)'
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="465a2a8f-2287-47f8-aa95-0fdd824c2441" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("465a2a8f-2287-47f8-aa95-0fdd824c2441")) {                    Plotly.newPlot(                        "465a2a8f-2287-47f8-aa95-0fdd824c2441",                        [{"alignmentgroup": "True", "hovertemplate": "\u0421\u0435\u0442\u044c=\u043d\u0435\u0442<br>\u041a\u043e\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e \u043f\u043e\u0441\u0430\u0434\u043e\u0447\u043d\u044b\u0445 \u043c\u0435\u0441\u0442=%{x}<extra></extra>", "legendgroup": "\u043d\u0435\u0442", "marker": {"color": "#636efa"}, "name": "\u043d\u0435\u0442", "notched": false, "offsetgroup": "\u043d\u0435\u0442", "orientation": "h", "showlegend": true, "type": "box", "x": [48, 35, 95, 50, 0, 240, 90, 150, 120, 5, 24, 140, 270, 320, 12, 2, 20, 30, 110, 150, 120, 6, 20, 192, 240, 120, 240, 45, 20, 45, 24, 50, 25, 40, 48, 85, 48, 10, 14, 20, 150, 49, 63, 30, 70, 40, 30, 30, 56, 45, 90, 30, 78, 20, 3, 240, 90, 80, 46, 110, 50, 0, 15, 30, 60, 7, 80, 10, 30, 40, 47, 30, 80, 180, 250, 200, 48, 110, 60, 80, 120, 49, 60, 60, 30, 25, 12, 14, 10, 16, 45, 6, 10, 48, 70, 420, 100, 48, 70, 5, 30, 34, 216, 45, 20, 40, 24, 70, 50, 25, 40, 49, 10, 48, 14, 45, 10, 20, 20, 0, 95, 28, 38, 0, 10, 42, 7, 20, 35, 24, 1, 2, 40, 30, 0, 2, 2, 0, 150, 0, 10, 98, 40, 35, 2, 42, 5, 10, 40, 240, 40, 60, 30, 40, 24, 20, 71, 10, 4, 100, 90, 32, 220, 0, 16, 120, 0, 12, 40, 3, 0, 12, 40, 0, 30, 95, 200, 0, 65, 55, 196, 120, 220, 48, 100, 40, 45, 0, 50, 40, 120, 8, 55, 25, 40, 35, 100, 45, 80, 70, 40, 35, 44, 48, 70, 38, 45, 98, 0, 50, 100, 4, 20, 80, 30, 40, 240, 76, 30, 38, 45, 50, 60, 220, 270, 20, 65, 75, 56, 48, 78, 35, 20, 144, 47, 83, 70, 0, 8, 10, 60, 165, 64, 32, 26, 90, 90, 45, 68, 25, 40, 50, 60, 48, 0, 0, 36, 50, 10, 160, 90, 50, 48, 4, 150, 80, 28, 200, 30, 150, 36, 60, 20, 240, 0, 20, 120, 35, 50, 1, 30, 40, 40, 40, 8, 0, 26, 20, 15, 40, 30, 40, 0, 0, 80, 50, 20, 96, 6, 50, 48, 200, 0, 20, 100, 90, 20, 0, 0, 94, 250, 10, 40, 50, 30, 180, 240, 20, 42, 45, 240, 24, 40, 70, 32, 50, 35, 50, 0, 10, 20, 40, 0, 48, 148, 55, 70, 20, 25, 30, 35, 95, 40, 200, 24, 40, 2, 50, 18, 80, 158, 10, 34, 220, 60, 120, 202, 90, 35, 60, 20, 240, 120, 45, 250, 30, 30, 4, 0, 7, 50, 20, 35, 80, 38, 55, 5, 40, 40, 32, 80, 86, 40, 50, 52, 49, 20, 15, 50, 48, 38, 80, 40, 25, 140, 50, 30, 38, 120, 35, 24, 40, 300, 40, 200, 40, 40, 54, 48, 30, 85, 40, 46, 24, 50, 98, 50, 88, 80, 25, 20, 40, 8, 300, 240, 46, 1, 95, 60, 80, 44, 60, 44, 10, 65, 20, 70, 95, 16, 84, 0, 0, 80, 50, 100, 48, 45, 70, 12, 25, 6, 5, 40, 246, 81, 20, 96, 3, 12, 100, 12, 78, 40, 15, 6, 70, 0, 240, 20, 23, 80, 0, 70, 28, 0, 45, 0, 20, 0, 150, 40, 150, 2, 45, 70, 30, 25, 80, 160, 2, 84, 39, 10, 30, 20, 0, 48, 99, 46, 60, 67, 40, 70, 10, 60, 150, 46, 0, 0, 71, 80, 4, 12, 60, 40, 46, 80, 16, 80, 4, 10, 80, 10, 75, 49, 36, 50, 180, 20, 96, 15, 98, 12, 120, 45, 100, 40, 40, 55, 55, 28, 28, 7, 16, 150, 24, 16, 200, 60, 100, 60, 150, 40, 25, 95, 35, 6, 0, 10, 42, 32, 15, 25, 50, 40, 1, 40, 45, 28, 12, 61, 20, 42, 40, 36, 75, 50, 39, 20, 47, 20, 2, 2, 0, 11, 12, 8, 12, 75, 40, 0, 240, 50, 35, 25, 38, 32, 48, 70, 36, 45, 40, 30, 24, 40, 90, 48, 45, 45, 48, 48, 25, 1, 120, 0, 10, 16, 60, 40, 85, 20, 35, 24, 50, 70, 0, 0, 0, 130, 98, 74, 10, 41, 30, 45, 90, 80, 15, 0, 26, 0, 45, 44, 70, 30, 25, 48, 30, 15, 90, 20, 60, 10, 0, 120, 40, 49, 240, 42, 0, 48, 150, 40, 40, 0, 25, 4, 80, 65, 110, 70, 50, 25, 10, 40, 30, 30, 40, 56, 25, 30, 90, 30, 95, 24, 34, 240, 240, 45, 45, 0, 95, 95, 0, 24, 90, 35, 7, 20, 58, 30, 45, 45, 50, 110, 46, 10, 120, 20, 20, 20, 80, 96, 30, 48, 75, 80, 4, 0, 40, 260, 30, 20, 42, 40, 60, 24, 48, 35, 40, 4, 12, 12, 4, 30, 15, 26, 300, 100, 16, 90, 50, 150, 32, 50 ...

# %% [markdown]
# - медианное значение для обеих групп - 40 мест;
# - для сетевых заведений закономерно видим меньший разброс количества посадочных мест — сетевые франшизы более уницифированы по формату, включая, вероятно, и количество посадочных мест;
# - несетевые заведения более разнообразны по этому показателю, а также выделяются выбросами выше 600 посадочных мест - бары в клубах, крупные рестораны и прочее;

# %%
top10_streets = (
    df3
    .groupby('street')
    .agg({'object_name':'count', 'number':'median'})
    .sort_values(by='object_name', ascending=False).head(10)
    .rename(columns={'object_name':'n_objects', 'number':'n_seats'})
    .reset_index()
    )

# %%
top10_streets
# Out:
#                     street  n_objects  n_seats
# 0            проспект Мира        196     45.0
# 1        Профсоюзная улица        180     24.5
# 2   Ленинградский проспект        170     40.0
# 3   Пресненская набережная        165     30.0
# 4         Варшавское шоссе        162     30.0
# 5       Ленинский проспект        147     45.0
# 6     проспект Вернадского        126     40.0
# 7     Кутузовский проспект        112     40.0
# 8          Каширское шоссе        110     25.0
# 9     Кировоградская улица        107     30.0

# %%
px.bar(
    top10_streets, 
    x='street', 
    y=['n_objects', 'n_seats'], 
    barmode='group', 
    title='Топ-10 улиц по количеству объектов и характерное для них количество посадочных мест',
    labels={'n_objects':'Количество объектов', 'n_seats':'Количество посадочных мест'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="3913bc5b-a9fb-4afe-89a5-b2d29e561029" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3913bc5b-a9fb-4afe-89a5-b2d29e561029")) {                    Plotly.newPlot(                        "3913bc5b-a9fb-4afe-89a5-b2d29e561029",                        [{"alignmentgroup": "True", "hovertemplate": "variable=n_objects<br>street=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "n_objects", "marker": {"color": "#636efa"}, "name": "n_objects", "offsetgroup": "n_objects", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [" \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442 \u041c\u0438\u0440\u0430", " \u041f\u0440\u043e\u0444\u0441\u043e\u044e\u0437\u043d\u0430\u044f \u0443\u043b\u0438\u0446\u0430", " \u041b\u0435\u043d\u0438\u043d\u0433\u0440\u0430\u0434\u0441\u043a\u0438\u0439 \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442", " \u041f\u0440\u0435\u0441\u043d\u0435\u043d\u0441\u043a\u0430\u044f \u043d\u0430\u0431\u0435\u0440\u0435\u0436\u043d\u0430\u044f", " \u0412\u0430\u0440\u0448\u0430\u0432\u0441\u043a\u043e\u0435 \u0448\u043e\u0441\u0441\u0435", " \u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439 \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442", " \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442 \u0412\u0435\u0440\u043d\u0430\u0434\u0441\u043a\u043e\u0433\u043e", " \u041a\u0443\u0442\u0443\u0437\u043e\u0432\u0441\u043a\u0438\u0439 \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442", " \u041a\u0430\u0448\u0438\u0440\u0441\u043a\u043e\u0435 \u0448\u043e\u0441\u0441\u0435", " \u041a\u0438\u0440\u043e\u0432\u043e\u0433\u0440\u0430\u0434\u0441\u043a\u0430\u044f \u0443\u043b\u0438\u0446\u0430"], "xaxis": "x", "y": [196.0, 180.0, 170.0, 165.0, 162.0, 147.0, 126.0, 112.0, 110.0, 107.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=n_seats<br>street=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "n_seats", "marker": {"color": "#EF553B"}, "name": "n_seats", "offsetgroup": "n_seats", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [" \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442 \u041c\u0438\u0440\u0430", " \u041f\u0440\u043e\u0444\u0441\u043e\u044e\u0437\u043d\u0430\u044f \u0443\u043b\u0438\u0446\u0430", " \u041b\u0435\u043d\u0438\u043d\u0433\u0440\u0430\u0434\u0441\u043a\u0438\u0439 \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442", " \u041f\u0440\u0435\u0441\u043d\u0435\u043d\u0441\u043a\u0430\u044f \u043d\u0430\u0431\u0435\u0440\u0435\u0436\u043d\u0430\u044f", " \u0412\u0430\u0440\u0448\u0430\u0432\u0441\u043a\u043e\u0435 \u0448\u043e\u0441\u0441\u0435", " \u041b\u0435\u043d\u0438\u043d\u0441\u043a\u0438\u0439 \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442", " \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442 \u0412\u0435\u0440\u043d\u0430\u0434\u0441\u043a\u043e\u0433\u043e", " \u041a\u0443\u0442\u0443\u0437\u043e\u0432\u0441\u043a\u0438\u0439 \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442", " \u041a\u0430\u0448\u0438\u0440\u0441\u043a\u043e\u0435 \u0448\u043e\u0441\u0441\u0435", " \u041a\u0438\u0440\u043e\u0432\u043e\u0433\u0440\u0430\u0434\u0441\u043a\u0430\u044f \u0443\u043b\u0438\u0446\u0430"], "xaxis": "x", "y": [45.0, 24.5, 40.0, 30.0, 30.0, 45.0, 40.0, 40.0, 25.0, 30.0], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor" ...

# %% [markdown]
# Не видно закономерности между количеством объектов на улице и медианным количеством посадочных мест.
#
# Можно было бы ожидать, что чем популярнее улица, тем более низкое медианное количество посадочных мест можно наблюдать для такой улицы (в первую очередь из-за дорогой аренды), однако для более обоснованной проверки такой гипотезы нужно как минимум нормировать количество объектов на улице на протяженность этих улиц. Для этого вновь пришлось бы обогощать данные, однако такая информация не несет большого значения для целей исследования, поэтому мы этого делать не будем.

# %% [markdown]
# Проверим согласно заданию, в каких районах Москвы находятся эти улицы.

# %%
df3.query('street in @top10_streets.street')['district'].unique()
# Out:
# array(['Донской', 'Нагорный', 'Чертаново Южное', 'Гагаринский',
#        'Ломоносовский', 'проспект Вернадского', 'Тропарево-никулино',
#        'Фили-давыдково', 'Нагатино-садовники', 'Москворечье-сабурово',
#        'Чертаново Центральное', 'Дорогомилово', 'Беговой', 'Аэропорт',
#        'Сокол', 'Якиманка', 'Обручевский', 'Мещанский', 'Останкинский',
#        'Алексеевский', 'Академический', 'Черемушки', 'Коньково',
#        'Теплый Стан', 'Раменки', 'Орехово-борисово Южное', nan,
#        'Чертаново Северное', 'Хорошевский', 'Орехово-борисово Северное',
#        'Ростокино', 'Свиблово', 'Ясенево', 'Южное Бутово', 'Пресненский',
#        'Ярославский'], dtype=object)

# %% [markdown]
# Не очень информативно, т.к. одна улица может входить в большое количество районов.
#
# Посмотрим на самые популярные улицы (а точнее на объекты на этих улицах) на карте для большей наглядности.

# %%
df3['lat_lng_geocode'][0]
# Out:
# '[55.8792377, 37.7141957]'

# %% [markdown]
# При парсинге координаты записались как строки `str` вместо листов `list`. Исправим это и перезапишем широту и долготу как отдельные `float` столбцы, т.к. с серией листов не удобно работать.
#
# P.S. My bad. Мог изначально так сделать при получении ответов от API по адресам.

# %%
# это превратит значения столбца из str в list
df3['lat_lng_geocode'] = df3['lat_lng_geocode'].map(eval)

# %%
df3['lat_lng_geocode'][0]
# Out:
# [55.8792377, 37.7141957]

# %%
df3['lat'] = df3['lat_lng_geocode'].map(lambda x: x[0])
df3['lng'] = df3['lat_lng_geocode'].map(lambda x: x[1])

# %%
df3[['lat_lng_geocode', 'lat', 'lng']].head()
# Out:
#             lat_lng_geocode        lat        lng
# 0  [55.8792377, 37.7141957]  55.879238  37.714196
# 1   [55.738252, 37.6733781]  55.738252  37.673378
# 2      [55.7355, 37.669608]  55.735500  37.669608
# 3  [55.8917906, 37.5734207]  55.891791  37.573421
# 4   [55.9049383, 37.572052]  55.904938  37.572052

# %%
df3 = df3.drop(columns='lat_lng_geocode')

# %% [markdown]
# Гуглим координаты центра Москвы

# %%
msk_center = {'lat': 55.751244, 'lng': 37.618423}

# %%
px.scatter_mapbox(
    df3.query('street in @top10_streets.street').dropna().sort_values(by='street', ascending=False), 
    lat='lat',
    lon='lng',
    center=dict(lat=msk_center['lat']-0.07, lon=msk_center['lng']), 
    zoom=9.5,
    height=800,
    color='street',
    mapbox_style='carto-positron',
    title='Топ-10 улиц Москвы по количеству объектов общественного питания'
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="8a1cd6d9-5795-4996-8f95-bcd52ae8c83f" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a1cd6d9-5795-4996-8f95-bcd52ae8c83f")) {                    Plotly.newPlot(                        "8a1cd6d9-5795-4996-8f95-bcd52ae8c83f",                        [{"hovertemplate": "street= \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442 \u041c\u0438\u0440\u0430<br>lat=%{lat}<br>lng=%{lon}<extra></extra>", "lat": [55.8448991, 55.8219714, 55.79145070000001, 55.7898454, 55.7733238, 55.7914556, 55.77728219999999, 55.7772947, 55.7772707, 55.793194, 55.8123869, 55.8219714, 55.8219714, 55.78342199999999, 55.8219714, 55.8219714, 55.8219714, 55.8219714, 55.8219714, 55.8219714, 55.8219714, 55.8219714, 55.8219714, 55.8219714, 55.774974, 55.8030158, 55.828413, 55.8243699, 55.7855821, 55.7881259, 55.7900143, 55.7900143, 55.7899811, 55.805341, 55.80689, 55.8092179, 55.8092179, 55.80758660000001, 55.80758660000001, 55.80758660000001, 55.80758660000001, 55.808173, 55.808954, 55.808954, 55.8102355, 55.8102355, 55.8102355, 55.8119903, 55.815893, 55.7774557, 55.7774557, 55.7774557, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8175399, 55.8076952, 55.77468210000001, 55.77468210000001, 55.8448991, 55.8448991, 55.8448991, 55.7774557, 55.8448991, 55.7774557, 55.803953, 55.7774557, 55.7774557, 55.7774557, 55.7774557, 55.78039399999999, 55.78039399999999, 55.820781, 55.820781, 55.820781, 55.820781, 55.77852499999999, 55.7806066, 55.7751271, 55.83732699999999, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.784062, 55.8092179, 55.783561, 55.8448991, 55.8150355, 55.8151367, 55.8151367, 55.7800634, 55.81437709999999, 55.808052, 55.786072, 55.808052, 55.8448991, 55.8448991, 55.7732446, 55.8018194, 55.78104, 55.783561, 55.7859559, 55.8448991, 55.8448991, 55.8448991, 55.810366, 55.810366, 55.7735956, 55.8448991, 55.8007573, 55.8007573, 55.8007573, 55.8007573, 55.8448991, 55.81240469999999, 55.84451199999999, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8381761, 55.83043, 55.8121349, 55.8009855, 55.82759009999999, 55.82759009999999, 55.82759009999999, 55.844082, 55.844082, 55.8194827, 55.808266, 55.808266, 55.8007573, 55.8007573, 55.8018194, 55.7859559, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.8448991, 55.787525, 55.80385279999999, 55.785587, 55.818714, 55.77797630000001, 55.7791228, 55.7791228, 55.7742593, 55.7797439, 55.7797439, 55.78012200000001, 55.780227, 55.780227, 55.78301099999999, 55.7818177, 55.8448991, 55.782267, 55.8448991, 55.8448991, 55.789517, 55.79090979999999, 55.79090979999999, 55.79090979999999, 55.836568, 55.7777287, 55.8368234, 55.793164, 55.8448991, 55.7811702, 55.8351597, 55.8351597, 55.8448991, 55.78729, 55.8448991, 55.78265099999999, 55.8448991], "legendgroup": " \u043f\u0440\u043e\u0441\u043f\u0435\u043a\u0442 \u041c\u0438\u0440\u0430", "lon": [37.6598303, 37.6451146, 37.635058, 37.6344021, 37.63257979999999, 37.6337199, 37.634527, 37.6358986, 37.6357094, 37.635863, 37.6363865, 37.6451146, 37.6451146, 37.6350391, 37.6451146, 37.6451146, 37.6451146, 37.6451146, 37.6451146, 37.6451146, 37.6451146, 37.6451146, 37.6451146, 37.6451146, 37.6330849, 37.6376655, 37.652035, 37.6459493, 37.6361206, 37.6353168, 37.6343585, 37.6343585, 37.633722, 37.635253, 37.6355401, 37.63636, 37.63636, 37.6380381, 37.6380381, 37.6380381, 37.6380381, 37.638315, 37.637968, 37.637968, 37.638527, 37.638527, 37.638527, 37.6392842, 37.6395399, 37.63339, 37.63339, 37.63339, 37.6598303, 37.6598303, 37.6598303, 37.6598303, 37.6598303, 37.6598303, 37.6598303, 37.6 ...

# %% [markdown]
# Видим, что в топ-10 улиц, действительно, попали по большей части попросту самые длинные улицы. Как мы уже отметили, для определенния популярных улиц нужно количество заведений на улице нормировать на протяженность улицы, чего мы делать не будем ввиду невысокой пользы такой информации для целей исследования.

# %% [markdown]
# Согласно заданию посмотрим на улицы с одним объектом общественного питания.

# %%
streets_w_one_object = df3.groupby('street').agg({'object_name':'count'})

# %%
streets_w_one_object = streets_w_one_object[streets_w_one_object <= 1].dropna().index.tolist()

# %%
len(streets_w_one_object)
# Out:
# 606

# %% [markdown]
# В Москве целых 606 улиц с 1 объектом общественного питания.
#
# Тем не менее, эта информация ничего нам не дает.

# %%
px.scatter_mapbox(
    df3.query('street in @streets_w_one_object').dropna(), 
    lat='lat',
    lon='lng',
    center=dict(lat=msk_center['lat']-0.05, lon=msk_center['lng']), 
    zoom=9,
    height=800,
    mapbox_style='carto-positron',
    title='Топ-10 улиц Москвы по количеству объектов общественного питания'
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="839e4f35-e3be-4b43-a860-807d83b8e5b6" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("839e4f35-e3be-4b43-a860-807d83b8e5b6")) {                    Plotly.newPlot(                        "839e4f35-e3be-4b43-a860-807d83b8e5b6",                        [{"hovertemplate": "lat=%{lat}<br>lng=%{lon}<extra></extra>", "lat": [55.7506357, 55.79072499999999, 55.810503, 55.7698802, 55.832015, 55.7631989, 55.74394400000001, 55.770377, 55.79105970000001, 55.72480299999999, 55.813365, 55.791208, 55.7348322, 55.785047, 55.77364410000001, 55.763825, 55.7692882, 55.7249, 55.7431053, 55.7313281, 55.756376, 55.742372, 55.72535860000001, 55.7483051, 55.796999, 55.70958299999999, 55.74519069999999, 55.673904, 55.764708, 55.76532470000001, 55.7347052, 55.81581019999999, 55.744812, 55.8191328, 55.758384, 55.739414, 55.7322127, 55.7974998, 55.6803816, 55.8611532, 55.7510343, 55.8061757, 55.75094130000001, 55.836082, 55.7458098, 55.7905959, 55.76770879999999, 55.6452705, 55.5438683, 55.7476526, 55.739707, 55.739688, 55.77679269999999, 55.791875, 55.713855, 55.793715, 55.7393055, 55.8459332, 55.873264, 55.800173, 55.81769569999999, 55.77349, 55.8327962, 55.759873, 55.756791, 55.743246, 55.7468292, 55.755649, 55.7380907, 55.733887, 55.72743999999999, 55.698795, 55.760684, 55.8176606, 55.824374, 55.809337, 55.8002066, 55.758361, 55.754655, 55.774997, 55.769757, 55.772701, 55.75895329999999, 55.61290899999999, 55.61174190000001, 55.844851, 55.599951, 55.73050509999999, 55.6119824, 55.6103247, 55.6753451, 55.6479943, 55.8591865, 55.88303, 55.7880037, 55.813564, 55.815918, 55.8164032, 55.8071444, 55.8173693, 55.8422529, 55.8863373, 55.82422469999999, 55.896431, 55.87490709999999, 55.874918, 55.812676, 55.895439, 55.7767142, 55.77331299999999, 55.77276519999999, 55.8330247, 55.806977, 55.784385, 55.783745, 55.82112, 55.775876, 55.730709, 55.79965199999999, 55.87493019999999, 55.940673, 55.634294, 55.543454, 55.65864699999999, 55.743488, 55.793539, 55.73913, 55.719238, 55.846055, 55.8408428, 55.795384, 55.783192, 55.791865, 55.798205, 55.7713214, 55.8033568, 55.7796161, 55.770697, 55.7931196, 55.790204, 55.78986949999999, 55.7768617, 55.795533, 55.80742499999999, 55.7898832, 55.7805857, 55.848288, 55.7891521, 55.80711100000001, 55.7824245, 55.792739, 55.7730099, 55.772909, 55.768867, 55.771395, 55.7565513, 55.769662, 55.767368, 55.990754, 55.766306, 55.768562, 55.7632456, 55.7924284, 55.7322575, 55.7354475, 55.7132322, 55.7220677, 55.745109, 55.710588, 55.647734, 55.65785289999999, 55.64651929999999, 55.760199, 55.771384, 55.750474, 55.7590409, 55.757865, 55.756778, 55.7549941, 55.7604131, 55.7519338, 55.7504245, 55.7449024, 55.7673261, 55.7318131, 55.737221, 55.7307419, 55.72264569999999, 55.7302265, 55.74155099999999, 55.753699, 55.7471937, 55.7559577, 55.75048109999999, 55.7475022, 55.746375, 55.7439082, 55.70807319999999, 55.73740300000001, 55.73512179999999, 55.742148, 55.707801, 55.833671, 55.877931, 55.8663231, 55.8744737, 55.879194, 55.8744706, 55.8666525, 55.8688614, 55.8762678, 55.8811384, 55.879931, 55.804011, 55.8047181, 55.788507, 55.78679500000001, 55.7757611, 55.79378699999999, 55.7894528, 55.8103309, 55.7855686, 55.7875131, 55.7558078, 55.724411, 55.72492889999999, 55.72293999999999, 55.96253489999999, 55.7175617, 55.715775, 55.7127038, 55.729791, 55.748057, 55.748676, 55.75019, 55.78708719999999, 55.674361, 55.7312545, 55.7243533, 55.7211934, 55.73450200000001, 55.6847139, 55.68426179999999, 55.6749911, 55.6974989, 55.6520094, 55.65726429999999, 55.71162, 55.7503284, 55.74537480000001, 55.7452516, 55.749069, 55.752467, 55.752805, 55.7335907, 55.5892892, 55.56350699999999, 55.778067, 55.885289, 55.83362529999999, 55.8682404, 55.7469402, 55.759536, 55.6 ...

# %% [markdown]
# Очевидно, что все эти 606 улиц с одним объектом общественного питания распределены по всей Москве (вплоть до Зеленограда), а не в каких-то особенных районах.

# %% [markdown]
# С заданиями разобрались. Теперь небольшое доп. исследование. Данных о потоке людей, как мы уже сказали, у нас нет, поэтому будем опираться на население района.
#
# Исследуем, какая доля населения района обеспечена посадочными местами.

# %%
final_report = (
    df3
    .query('object_type == "кафе"')
    .groupby('district')
    .agg({
        'lat':'mean', 
        'lng':'mean', 
        'object_name':'count', 
        'number':'sum', 
        'pop':'mean'
        })
    .reset_index()
    .sort_values(by='pop', ascending=False)
    .dropna()
    .rename(columns={
        'lat':'centroid_lat',
        'lng':'centroid_lng',
        'object_name':'n_objects',
        'number':'n_seats'
        })
    )

# %%
final_report.head()
# Out:
#             district  centroid_lat  centroid_lng  n_objects  n_seats       pop
# 62           Марьино     55.654217     37.746129         64     1647  254142.0
# 22   Выхино-жулебино     55.698930     37.833422         40     1565  225493.0
# 136     Южное Бутово     55.542004     37.536439         28     1585  210783.0
# 66            Митино     55.845902     37.362984         43     1664  195476.0
# 85          Отрадное     55.861476     37.596333         55     3464  185745.0

# %%
final_report['seats_per_pop'] = (final_report['n_seats'] / final_report['pop']).round(3)

# %%
final_report.head()
# Out:
#             district  centroid_lat  centroid_lng  n_objects  n_seats  \
# 62           Марьино     55.654217     37.746129         64     1647
# 22   Выхино-жулебино     55.698930     37.833422         40     1565
# 136     Южное Бутово     55.542004     37.536439         28     1585
# 66            Митино     55.845902     37.362984         43     1664
# 85          Отрадное     55.861476     37.596333         55     3464
#
#           pop  seats_per_pop
# 62   254142.0          0.006
# 22   225493.0          0.007
# 136  210783.0          0.008
# 66   195476.0          0.009
# 85   185745.0          0.019

# %%
final_report['seats_per_pop'].describe()
# Out:
# count    121.000000
# mean       0.022207
# std        0.036716
# min        0.001000
# 25%        0.006000
# 50%        0.010000
# 75%        0.020000
# max        0.268000
# Name: seats_per_pop, dtype: float64

# %%
px.scatter_mapbox(
    final_report,
    lat='centroid_lat',
    lon='centroid_lng',
    center=dict(lat=msk_center['lat'], lon=msk_center['lng']), 
    zoom=9,
    color='seats_per_pop',
    range_color=[0, 0.075],
    text='district',
    size='pop',
    size_max=30,
    color_continuous_scale=px.colors.diverging.RdYlGn,
    height=800,
    mapbox_style='carto-positron',
    title='Обеспеченность населения района посадочными местами в кафе'
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="1678f940-06d7-429e-965f-68e99be2782b" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1678f940-06d7-429e-965f-68e99be2782b")) {                    Plotly.newPlot(                        "1678f940-06d7-429e-965f-68e99be2782b",                        [{"hovertemplate": "pop=%{marker.size}<br>district=%{text}<br>centroid_lat=%{lat}<br>centroid_lng=%{lon}<br>seats_per_pop=%{marker.color}<extra></extra>", "lat": [55.65421705312501, 55.69893043, 55.54200353571428, 55.84590228372092, 55.861476258181845, 55.61286757222222, 55.77818999473684, 55.67401962631579, 55.85766631304347, 55.81469571724139, 55.80451107222221, 55.89090329189188, 55.64365820307691, 55.59801368333333, 55.74188002272728, 55.59080908571429, 55.60715574210527, 55.702461409090915, 55.701911428358216, 55.752390217857176, 55.71520043999999, 55.63013815945944, 55.618437882352936, 55.61783636, 55.68901753157894, 55.629385771428566, 55.76893773333334, 55.75821812923494, 55.887036725, 55.657272138461536, 55.65264156153845, 55.66534918484847, 55.74205201708858, 55.729643033333325, 55.64003830588235, 55.67836478148148, 55.61282981199998, 55.632297108333326, 55.79935375454546, 55.66317906666668, 55.76324297534233, 55.6370081375, 55.81535800740738, 55.719274718750015, 55.684561954545444, 55.8456189095238, 55.732211110526336, 55.73886951666666, 55.79241346976744, 55.705217516666664, 55.84402348444443, 55.972932199999995, 55.83250247727272, 55.886649462499996, 55.747931714285706, 55.868182394594626, 55.5701398037037, 55.753135525581385, 55.71156220849041, 55.744767043859675, 55.88792219130435, 55.779141280327835, 55.79618491851853, 55.86396832222221, 55.58426575714285, 55.86655352631578, 55.679408403571415, 55.80785013636365, 55.660109709859164, 55.69589171724138, 55.896788470000004, 55.868718925, 55.86548434705883, 55.823188654545454, 55.67538405434784, 55.692118900000004, 55.87661713076925, 55.76037299999999, 55.715449208333325, 55.690557590243934, 55.66331724285714, 55.64387380500001, 55.81509511395349, 55.865523257142854, 55.80200819310345, 55.793755918181816, 55.7693721148571, 55.74372360000002, 55.71370794255324, 55.78639777962954, 55.80583658124999, 55.82477669827586, 55.793936202298866, 55.68527014736841, 55.677435038888895, 55.82027843783783, 55.84751895384616, 55.79231248518518, 55.77055887005083, 55.80612450666668, 55.79789568709677, 55.735069931578956, 55.879835850000006, 55.86173207692306, 55.706416075903554, 55.77439723111111, 55.73362071904761, 56.00615511666667, 55.99206314444445, 55.83605120833331, 55.82536210000001, 55.92351869999999, 55.7511901833333, 55.83527803333333, 55.987550529999986, 55.89456837647058, 55.645714, 55.98103049999999, 55.73330431733333, 55.60959941818181, 55.94196843333333], "legendgroup": "", "lon": [37.74612881562502, 37.833421772499996, 37.536439046428576, 37.36298400465116, 37.59633281818183, 37.52184688611111, 37.46932832631579, 37.757496918421054, 37.43412776521739, 37.78855981724138, 37.399708200000006, 37.602839645945934, 37.524584729230774, 37.66687176666667, 37.41974870454546, 37.60079507714286, 37.726468326315796, 37.77019335909091, 37.516582997014936, 37.76872052142858, 37.413122400000006, 37.50701208108109, 37.74455885294117, 37.71519041, 37.45605412105264, 37.65984868095238, 37.832564100000006, 37.56858372650271, 37.660580800000005, 37.596167323076926, 37.40593926923077, 37.47675244242424, 37.66225872658226, 37.82391848333334, 37.3512952882353, 37.679656111111115, 37.603600432, 37.61010939166666, 37.484457884848474, 37.555588276666654, 37.65501970328766, 37.7600907125, 37.72294187037037, 37.77972546875, 37.57191571363635, 37.440764811904764, 37.580852123026325, 37.8586318, 37.77847681162791, 37.73312001666667, 37.49588499555554, 37.172 ...

# %% [markdown]
# **Зеленые центральные районы имеют наибольший поток людей. Красные — наименьший. Открывать робо-ресторан лучше в зеленых районах с большим потоком. Естественной внешней границей для открытия может выступить Садовое кольцо. В него входят районы: Мещанскй, Тверской, Арбат, Якиманка, Замоскворечье, Басманный. **
#
# - на центральные районы приходится избыточное количество посадочных мест на население района из-за того, что в центре имеем большой туристический (и не только) поток людей;
# - из-за того, что робо-кафе —  весьма специфичный формат, он будет являться аналогом достопримечательности, которой требуется постоянный поток новых людей. Именно поэтому некоторые спальные районы с крупным населением и небольшим количеством кафе **не подойдут** —  нас интересует максимальный охват новых посетителей, а не попытка в удержание покупателей;

# %%
good_districts = ['Мещанский', 'Тверской', 'Арбат', 'Якиманка', 'Замоскворечье','Басманный']

# %%
px.scatter_mapbox(
    final_report.query('district in @good_districts'),
    lat='centroid_lat',
    lon='centroid_lng',
    center=dict(lat=msk_center['lat']-0.005, lon=msk_center['lng']), 
    zoom=12,
    color='district',
    range_color=[0, 0.075],
    size='pop',
    size_max=30,
    height=800,
    mapbox_style='carto-positron',
    title='Перспективные районы для открытия робо-кафе'
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="6cb1cf6e-7e50-4357-9dab-5d7357af2ec2" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cb1cf6e-7e50-4357-9dab-5d7357af2ec2")) {                    Plotly.newPlot(                        "6cb1cf6e-7e50-4357-9dab-5d7357af2ec2",                        [{"hovertemplate": "district=\u0411\u0430\u0441\u043c\u0430\u043d\u043d\u044b\u0439<br>pop=%{marker.size}<br>centroid_lat=%{lat}<br>centroid_lng=%{lon}<extra></extra>", "lat": [55.76324297534233], "legendgroup": "\u0411\u0430\u0441\u043c\u0430\u043d\u043d\u044b\u0439", "lon": [37.65501970328766], "marker": {"color": "#636efa", "size": [110897.0], "sizemode": "area", "sizeref": 123.21888888888888}, "mode": "markers", "name": "\u0411\u0430\u0441\u043c\u0430\u043d\u043d\u044b\u0439", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "district=\u0422\u0432\u0435\u0440\u0441\u043a\u043e\u0439<br>pop=%{marker.size}<br>centroid_lat=%{lat}<br>centroid_lng=%{lon}<extra></extra>", "lat": [55.7693721148571], "legendgroup": "\u0422\u0432\u0435\u0440\u0441\u043a\u043e\u0439", "lon": [37.60627565971423], "marker": {"color": "#EF553B", "size": [77947.0], "sizemode": "area", "sizeref": 123.21888888888888}, "mode": "markers", "name": "\u0422\u0432\u0435\u0440\u0441\u043a\u043e\u0439", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "district=\u041c\u0435\u0449\u0430\u043d\u0441\u043a\u0438\u0439<br>pop=%{marker.size}<br>centroid_lat=%{lat}<br>centroid_lng=%{lon}<extra></extra>", "lat": [55.77055887005083], "legendgroup": "\u041c\u0435\u0449\u0430\u043d\u0441\u043a\u0438\u0439", "lon": [37.62742571928925], "marker": {"color": "#00cc96", "size": [61452.0], "sizemode": "area", "sizeref": 123.21888888888888}, "mode": "markers", "name": "\u041c\u0435\u0449\u0430\u043d\u0441\u043a\u0438\u0439", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "district=\u0417\u0430\u043c\u043e\u0441\u043a\u0432\u043e\u0440\u0435\u0447\u044c\u0435<br>pop=%{marker.size}<br>centroid_lat=%{lat}<br>centroid_lng=%{lon}<extra></extra>", "lat": [55.735069931578956], "legendgroup": "\u0417\u0430\u043c\u043e\u0441\u043a\u0432\u043e\u0440\u0435\u0447\u044c\u0435", "lon": [37.63217457157894], "marker": {"color": "#ab63fa", "size": [59305.0], "sizemode": "area", "sizeref": 123.21888888888888}, "mode": "markers", "name": "\u0417\u0430\u043c\u043e\u0441\u043a\u0432\u043e\u0440\u0435\u0447\u044c\u0435", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "district=\u0410\u0440\u0431\u0430\u0442<br>pop=%{marker.size}<br>centroid_lat=%{lat}<br>centroid_lng=%{lon}<extra></extra>", "lat": [55.7511901833333], "legendgroup": "\u0410\u0440\u0431\u0430\u0442", "lon": [37.592125640476155], "marker": {"color": "#FFA15A", "size": [36308.0], "sizemode": "area", "sizeref": 123.21888888888888}, "mode": "markers", "name": "\u0410\u0440\u0431\u0430\u0442", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}, {"hovertemplate": "district=\u042f\u043a\u0438\u043c\u0430\u043d\u043a\u0430<br>pop=%{marker.size}<br>centroid_lat=%{lat}<br>centroid_lng=%{lon}<extra></extra>", "lat": [55.73330431733333], "legendgroup": "\u042f\u043a\u0438\u043c\u0430\u043d\u043a\u0430", "lon": [37.613994100000006], "marker": {"color": "#19d3f3", "size": [27911.0], "sizemode": "area", "sizeref": 123.21888888888888}, "mode": "markers", "name": "\u042f\u043a\u0438\u043c\u0430\u043d\u043a\u0430", "showlegend": true, "subplot": "mapbox", "type": "scattermapbox"}],                        {"height": 800, "legend": {"itemsizing": "constant", "title": {"text": "district"}, "tracegroupgap": 0}, "mapbox": {"center": {"lat": 55.746244, "lon": 37.6 ...

# %%
px.box(
    df3.query('district in @good_districts'), 
    x='number',
    labels={'number':'Количество посадочных мест'},
    title='Характерное количество посадочных мест внутри Садового кольца'
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="07d0389e-81e4-4968-9005-593a5eb15714" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07d0389e-81e4-4968-9005-593a5eb15714")) {                    Plotly.newPlot(                        "07d0389e-81e4-4968-9005-593a5eb15714",                        [{"alignmentgroup": "True", "hovertemplate": "\u041a\u043e\u043b\u0438\u0447\u0435\u0441\u0442\u0432\u043e \u043f\u043e\u0441\u0430\u0434\u043e\u0447\u043d\u044b\u0445 \u043c\u0435\u0441\u0442=%{x}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "h", "showlegend": false, "type": "box", "x": [10, 20, 50, 125, 25, 20, 100, 40, 48, 85, 48, 10, 14, 20, 150, 49, 63, 48, 30, 120, 40, 70, 90, 22, 40, 40, 30, 30, 56, 38, 45, 220, 90, 30, 78, 20, 3, 80, 48, 10, 160, 30, 30, 98, 34, 216, 54, 45, 20, 580, 20, 22, 100, 124, 35, 82, 10, 35, 40, 20, 76, 30, 38, 120, 30, 50, 50, 60, 270, 20, 65, 75, 56, 48, 78, 35, 20, 20, 70, 144, 60, 47, 83, 48, 41, 96, 70, 0, 8, 60, 10, 60, 60, 165, 64, 35, 80, 144, 32, 320, 10, 40, 30, 0, 30, 26, 35, 20, 50, 50, 4, 150, 80, 20, 28, 50, 143, 90, 15, 40, 50, 50, 100, 24, 40, 26, 70, 50, 32, 50, 35, 65, 48, 10, 34, 220, 60, 190, 120, 202, 90, 50, 40, 35, 38, 80, 55, 15, 131, 20, 60, 30, 30, 48, 4, 0, 7, 80, 38, 55, 80, 86, 50, 45, 94, 99, 46, 60, 67, 40, 100, 70, 10, 0, 60, 150, 46, 0, 0, 71, 120, 12, 120, 45, 100, 40, 40, 55, 55, 28, 28, 70, 35, 8, 6, 0, 24, 50, 40, 45, 28, 12, 35, 25, 36, 10, 64, 40, 25, 36, 30, 16, 32, 40, 20, 60, 40, 85, 20, 35, 15, 24, 20, 25, 24, 10, 40, 30, 30, 90, 30, 20, 58, 30, 50, 43, 30, 45, 46, 10, 120, 90, 20, 20, 65, 48, 20, 80, 96, 15, 30, 48, 75, 0, 40, 38, 12, 12, 40, 40, 30, 15, 26, 6, 30, 46, 30, 90, 75, 35, 50, 50, 95, 50, 16, 45, 20, 120, 140, 46, 30, 50, 45, 8, 50, 20, 80, 40, 39, 80, 35, 30, 120, 143, 42, 46, 50, 90, 96, 12, 48, 40, 60, 68, 75, 45, 30, 70, 50, 15, 20, 56, 43, 45, 54, 43, 10, 12, 130, 4, 40, 30, 48, 0, 9, 90, 35, 25, 80, 5, 104, 65, 30, 10, 30, 50, 20, 50, 26, 30, 60, 60, 47, 0, 10, 10, 30, 40, 5, 60, 20, 160, 20, 30, 48, 48, 90, 30, 45, 90, 45, 80, 45, 50, 25, 6, 8, 48, 20, 18, 45, 50, 16, 36, 90, 38, 80, 40, 20, 46, 20, 31, 1, 4, 15, 5, 5, 8, 15, 15, 15, 20, 15, 20, 15, 20, 5, 15, 10, 5, 5, 15, 15, 15, 10, 12, 10, 18, 13, 6, 10, 10, 10, 34, 62, 90, 50, 50, 40, 50, 35, 12, 0, 150, 30, 40, 35, 40, 54, 37, 36, 48, 35, 60, 43, 36, 36, 10, 20, 30, 5, 84, 30, 70, 38, 48, 16, 60, 20, 20, 30, 90, 70, 70, 28, 55, 47, 15, 64, 41, 110, 50, 42, 60, 30, 15, 45, 89, 36, 48, 50, 24, 20, 32, 40, 8, 30, 25, 50, 40, 35, 50, 48, 170, 10, 20, 20, 35, 48, 48, 18, 140, 50, 25, 96, 0, 0, 0, 40, 60, 20, 24, 16, 44, 40, 48, 4, 48, 40, 45, 60, 9, 53, 257, 38, 30, 70, 115, 40, 65, 50, 30, 44, 15, 100, 230, 22, 12, 25, 50, 6, 70, 40, 40, 138, 50, 26, 30, 16, 74, 28, 24, 50, 20, 30, 28, 60, 8, 30, 40, 20, 10, 52, 32, 25, 150, 72, 80, 68, 70, 70, 120, 84, 30, 30, 40, 75, 170, 85, 50, 120, 200, 35, 80, 45, 150, 18, 50, 50, 20, 30, 20, 90, 50, 36, 80, 80, 50, 60, 40, 25, 88, 88, 82, 60, 98, 70, 56, 72, 32, 50, 36, 66, 100, 50, 30, 64, 55, 65, 25, 0, 170, 89, 0, 100, 90, 50, 44, 25, 49, 40, 70, 20, 80, 35, 25, 0, 50, 12, 15, 60, 64, 15, 30, 50, 80, 80, 500, 400, 112, 40, 92, 50, 96, 35, 120, 80, 16, 40, 6, 7, 46, 80, 280, 109, 60, 146, 110, 15, 120, 75, 5, 100, 140, 10, 30, 61, 306, 55, 272, 180, 45, 50, 95, 108, 138, 1, 1, 80, 100, 50, 55, 60, 65, 50, 45, 30, 48, 40, 80, 40, 60, 156, 102, 52, 80, 15, 0, 90, 144, 0, 12, 100, 40, 75, 40, 60, 70, 55, 35, 70, 120, 30, 50, 35, 40, 47, 65, 48, 282, 150, 14, 60, 70, 40, 45, 90, 10, 2, 30, 0, 98, 35, 45, 20, 45, 90, 25, 4, 45, 150, 34, 95, 40, 180, 40, 40, 50, 40, 80, 120, 80, 175, 120, 45, 140, 45, 90, 48, 60, 26, 40,  ...

# %% [markdown]
# Для выбранных нами районов адекватным количеством посадочных мест выглядит значение между медианой и верхним квартилем (от 45 до 80 мест). Мы не рассматриваем нижний квартиль из-за того, т.к. для дорогого робо-кафе в меньшей степени подходит формат бюджетной миниатюрной кафешки.

# %% [markdown]
# ## 7. Результаты исследования <a name="7"></a>

# %% [markdown]
# - наиболее распространенный формат объектов общественного питания — кафе. Нашему робо-заведению следует рассмотреть именно этот формат в первую очередь;
# - оптимальное количество посадочных мест от 45 до 80;
# - оптимальные районы — районы внутри Садового кольца с большим туристическим потоком людей: Мещанский, Тверской, Арбат, Якиманка, Замоскворечье и Басманный.
#
# Презентация для инвесторов: https://drive.google.com/file/d/1fy85g-DAT6_jlOGLcQzLXicaNeM_QFLo/view?usp=sharing
